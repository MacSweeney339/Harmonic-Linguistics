# %% [markdown]
# # Visual Insperation

# %% [markdown]
# The following iframes serve as references and inspiration for the end product I would like to develop with my analysis / capstone.

# %%
from IPython.display import HTML
HTML('<iframe src=http://poly-graph.co/vocabulary.html width=1000 height=350></iframe>')
# Out:
# <iframe src=http://poly-graph.co/vocabulary.html width=1000 height=350></iframe>

# %%
from IPython.display import HTML
HTML('<iframe src=http://www.nytimes.com/interactive/2012/02/13/us/politics/2013-budget-proposal-graphic.html?_r=0 width=1000 height=350></iframe>')
# Out:
# <iframe src=http://www.nytimes.com/interactive/2012/02/13/us/politics/2013-budget-proposal-graphic.html?_r=0 width=1000 height=350></iframe>

# %%
from IPython.display import HTML
HTML('<iframe src=http://mbostock.github.io/d3/talk/20111116/pack-hierarchy.html width=1000 height=350></iframe>')
# Out:
# <iframe src=http://mbostock.github.io/d3/talk/20111116/pack-hierarchy.html width=1000 height=350></iframe>

# %%
ls
# Out:
# D3/      Genius/  Spotify/ Wiki/    img/

# %%
from IPython.display import Image
Image(filename='img/example3.png')

# %%
from IPython.display import Image
Image(filename='img/example4.png')

# %%
from IPython.display import HTML
HTML('<iframe src=http://www.artorithmia.com/ width=1000 height=350></iframe>')
# Out:
# <iframe src=http://www.artorithmia.com/ width=1000 height=350></iframe>

# %%
from IPython.display import HTML
HTML('<iframe src=http://www.visualcinnamon.com/2013/07/self-organizing-maps-creating-hexagonal.html width=1000 height=350></iframe>')
# Out:
# <iframe src=http://www.visualcinnamon.com/2013/07/self-organizing-maps-creating-hexagonal.html width=1000 height=350></iframe>

# %%
from IPython.display import HTML
HTML('<iframe src=http://www.dailyinformation.net/artificial-intelligence-and-statistics-principal-component-analysis-and-self-organizing-maps/index.htm width=1000 height=350></iframe>')
# Out:
# <iframe src=http://www.dailyinformation.net/artificial-intelligence-and-statistics-principal-component-analysis-and-self-organizing-maps/index.htm width=1000 height=350></iframe>
