# %%
import spotipy
from spotipy import Spotify, util, oauth2
from Spotify_Credentials import Spotify_Credentials
import sys
import base64

# %%
code = authorization.get_access_token()
spot_creds = Spotify_Credentials()
token = util.prompt_for_user_token(spot_creds.user_id, None, spot_creds.client_id, spot_creds.client_secret, spot_creds.redirect_uri)
authorization = spotipy.oauth2.SpotifyClientCredentials(spot_creds.client_id, spot_creds.client_secret)
spotify = Spotify(auth=code)

# %%
results = spotify.search(q='artist:' + 'Talib', type='artist')

# %%
dir(authorization)
authorization.get_access_token()
# Out:
# u'BQAwtJJbi5gr-YgRmm0bI6xVJBReXOZCMM01ewEFMBI4aQ2YtP6iVGO1freq5Vsn2fduaezN8PsvtPGMaZ1lDA'

# %%
results['artists']['items'][0]
# Out:
# {u'external_urls': {u'spotify': u'https://open.spotify.com/artist/0lEssBAxQl2In4RpaB1C2Y'},
#  u'followers': {u'href': None, u'total': 132013},
#  u'genres': [u'alternative hip hop',
#   u'dirty south rap',
#   u'east coast hip hop',
#   u'hardcore hip hop',
#   u'hip hop',
#   u'pop rap',
#   u'rap',
#   u'southern hip hop',
#   u'turntablism'],
#  u'href': u'https://api.spotify.com/v1/artists/0lEssBAxQl2In4RpaB1C2Y',
#  u'id': u'0lEssBAxQl2In4RpaB1C2Y',
#  u'images': [{u'height': 641,
#    u'url': u'https://i.scdn.co/image/e1299eb0ff3c1fab68d4524fb1de84270fbf76e9',
#    u'width': 1000},
#   {u'height': 410,
#    u'url': u'https://i.scdn.co/image/15d0f3badc293ec1df1a9a2212ae690dd406fdc2',
#    u'width': 639},
#   {u'height': 128,
#    u'url': u'https://i.scdn.co/image/a5b9a998849d43f9c86e6840b350dc267e2af865',
#    u'width': 200},
#   {u'height': 41,
#    u'url': u'https://i.scdn.co/image/a2f3df22507c45ba1b6d8218f32b895f27f06d7e',
#    u'width': 64}],
#  u'name': u'Talib Kweli',
# ...

# %%
dir(spot_creds)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__doc__',
#  '__format__',
#  '__getattribute__',
#  '__hash__',
#  '__init__',
#  '__module__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'base_url',
#  'client_id',
#  'client_secret',
#  'redirect_uri',
#  'user_id']

# %%
#header = {'Authorization' : 'Basic ' + base64.standard_b64encode(spot_creds.client_id + ':' + spot_creds.client_secret)}
#body = {'grant_type': 'authorization_code' , 'code': code, 'redirect_uri': spot_creds.redirect_uri}

# %%
for i in range(len(spotify.categories()['categories']['items'])):
    print spotify.categories()['categories']['items'][i]['name']
# Out:
# Top Lists
# Mood
# Party
# Pop
# Trending
# Focus
# Rock
# Indie
# EDM/Dance
# Chill
# Dinner
# Sleep
# Hip Hop
# Workout
# RnB
# Country
# Folk & Americana
# Metal
# Soul
# Travel

# %%
for i in range(len(spotify.categories()['categories']['items'])):
    x = spotify.categories()['categories']['items'][i]['name']
    if x == 'Hip Hop':
        hh = spotify.categories()['categories']['items'][i]
    else:
        pass

# %%
hh
# Out:
# {u'href': u'https://api.spotify.com/v1/browse/categories/hiphop',
#  u'icons': [{u'height': 274,
#    u'url': u'https://t.scdn.co/media/original/hip-274_0a661854d61e29eace5fe63f73495e68_274x274.jpg',
#    u'width': 274}],
#  u'id': u'hiphop',
#  u'name': u'Hip Hop'}

# %%
dir(spotify)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__doc__',
#  '__format__',
#  '__getattribute__',
#  '__hash__',
#  '__init__',
#  '__module__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_auth',
#  '_auth_headers',
#  '_delete',
#  '_get',
#  '_get_id',
#  '_get_uri',
#  '_internal_call',
#  '_post',
#  '_put',
#  '_session',
#  '_warn',
#  'album',
#  'album_tracks',
#  'albums',
#  'artist',
#  'artist_albums',
#  'artist_related_artists',
#  'artist_top_tracks',
#  'artists',
#  'audio_features',
#  'categories',
#  'category_playlists',
#  'client_credentials_manager',
#  'current_user',
#  'current_user_followed_artists',
#  'current_user_saved_albums',
#  'current_user_saved_tracks',
#  'current_user_saved_tracks_add',
#  'current_user_saved_tracks_contains',
#  'current_user_saved_tracks_delete',
#  'current_user_top_artists',
#  'current_user_top_tracks',
# ...

# %%
spotify.category_playlists(category_id='hiphop')
# Out:
# {u'playlists': {u'href': u'https://api.spotify.com/v1/browse/categories/hiphop/playlists?offset=0&limit=20',
#   u'items': [{u'collaborative': False,
#     u'external_urls': {u'spotify': u'http://open.spotify.com/user/spotify/playlist/5yolys8XG4q7YfjYGl5Lff'},
#     u'href': u'https://api.spotify.com/v1/users/spotify/playlists/5yolys8XG4q7YfjYGl5Lff',
#     u'id': u'5yolys8XG4q7YfjYGl5Lff',
#     u'images': [{u'height': None,
#       u'url': u'https://u.scdn.co/images/pl/default/91bdd7b54712cc83aafeea0c7b0e92f5081b30f0',
#       u'width': None}],
#     u'name': u'Rap Caviar',
#     u'owner': {u'external_urls': {u'spotify': u'http://open.spotify.com/user/spotify'},
#      u'href': u'https://api.spotify.com/v1/users/spotify',
#      u'id': u'spotify',
#      u'type': u'user',
#      u'uri': u'spotify:user:spotify'},
#     u'public': None,
#     u'snapshot_id': u'M3wGCQ9cwufoXzXICQwBzdhkzq9g4tlSptqUlI1t6cVHWGFDfKOAmsIDRbnKoTf8',
# ...

# %%
len(spotify.category_playlists(category_id='hiphop')['playlists'])
# Out:
# ---------------------------------------------------------------------------
# SpotifyException                          Traceback (most recent call last)
# <ipython-input-32-c394b8b8fa17> in <module>()
# ----> 1 len(spotify.category_playlists(category_id='hiphop')['playlists'])
#
# /Users/sean/anaconda2/lib/python2.7/site-packages/spotipy/client.pyc in category_playlists(self, category_id, country, limit, offset)
#     650         '''
#     651         return self._get('browse/categories/' + category_id + '/playlists', country=country,
# --> 652             limit=limit, offset=offset)
#     653
#     654     def recommendations(self, seed_artists=[], seed_genres=[], seed_tracks=[],
#
# /Users/sean/anaconda2/lib/python2.7/site-packages/spotipy/client.pyc in _get(self, url, args, payload, **kwargs)
#     131         while retries > 0:
#     132             try:
# --> 133                 return self._internal_call('GET', url, payload, kwargs)
# ...

# %%
i = 0
playlists = []
while True:
    playlist = spotify.category_playlists(category_id='hiphop',offset=i,limit=1)['playlists']['items'][0]['name']
    playlists.append(playlist)
    i += 1
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-126-0c1de3f6b75e> in <module>()
#       2 playlists = []
#       3 while True:
# ----> 4     playlist = spotify.category_playlists(category_id='hiphop',offset=i,limit=1)['playlists']['items'][0]['name']
#       5     playlists.append(playlist)
#       6     i += 1
#
# IndexError: list index out of range

# %%
playlists
# Out:
# [u'Rap Caviar',
#  u'Most Necessary',
#  u'Signed XOXO',
#  u'Gold School',
#  u'Get Turnt',
#  u'Love, Sex & Water',
#  u'African Heat',
#  u'Workout Twerkout',
#  u'State of Mind',
#  u'Grime Shutdown',
#  u"If It Wasn't For Gucci",
#  u'Cali Fire',
#  u'Genre Bender',
#  u'The Realest Down South',
#  u'This Is: Booba',
#  u'This Is: Drake',
#  u'Get Your Mind Right',
#  u'Dancehall Official',
#  u'Mellow Bars',
#  u'Lush Vibes',
#  u'This Is: A$AP Rocky',
#  u'We Everywhere',
#  u'Strength of Street Knowledge',
#  u'Black History Salute',
#  u'Power Workout',
#  u'This Is: Gucci Mane',
#  u'G.O.O.D Music',
#  u'ill Lyricist',
#  u'Urban Poet',
#  u'K-Hip Hop Beats',
#  u"I Love My 90's Hip Hop"]

# %%
spotify.categories()
# Out:
# {u'categories': {u'href': u'https://api.spotify.com/v1/browse/categories?offset=0&limit=20',
#   u'items': [{u'href': u'https://api.spotify.com/v1/browse/categories/toplists',
#     u'icons': [{u'height': 275,
#       u'url': u'https://t.scdn.co/media/derived/toplists_11160599e6a04ac5d6f2757f5511778f_0_0_275_275.jpg',
#       u'width': 275}],
#     u'id': u'toplists',
#     u'name': u'Top Lists'},
#    {u'href': u'https://api.spotify.com/v1/browse/categories/mood',
#     u'icons': [{u'height': 274,
#       u'url': u'https://t.scdn.co/media/original/mood-274x274_976986a31ac8c49794cbdc7246fd5ad7_274x274.jpg',
#       u'width': 274}],
#     u'id': u'mood',
#     u'name': u'Mood'},
#    {u'href': u'https://api.spotify.com/v1/browse/categories/party',
#     u'icons': [{u'height': 274,
#       u'url': u'https://t.scdn.co/media/links/partyicon_274x274.jpg',
#       u'width': 274}],
#     u'id': u'party',
#     u'name': u'Party'},
# ...
