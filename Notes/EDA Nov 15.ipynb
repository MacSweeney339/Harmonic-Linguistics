# %% [markdown]
# # Hip Hop Lyrics EDA and Exploration

# %%
from pymongo import MongoClient
from bson.objectid import ObjectId

# %%
# pull data from mongo to get a list of artists and their song lyrics
client = MongoClient()

# %%
mack_dev = client['mack']

# %%
musician_dev = mack_dev['musician']
song_dev = mack_dev['song']
album_dev = mack_dev['album']

# %%
# find all songs that successfully have lyrics
song_cursor = song_dev.find({'lyrics': {'$exists': True, '$nin': ['No Result','AttributeError', 'TypeError']}})

# %%
song_list = [song for song in song_cursor]

# %%
# how many songs do we have?
len(song_list)
# Out:
# 50908

# %%
# how many distinct artists do we have
len(set([song['musician_id'] for song in song_list]))
# Out:
# 1113

# %%
# lets check how long it will take for our lyrics to be collected

# %%
process_times = [song['process_time'] for song in song_list]

# %%
time_to_complete_gathering = sum(process_times) / 60 / 60 / 24

# %%
print round(time_to_complete_gathering), ' days'
# Out:
# 1.0  days

# %%
# oh boy that's a long time

# %% [markdown]
# # Let's try some NLP with our EDA

# %%
# write functions to clean and tokenize lyrics
import nltk
from nltk.corpus import stopwords
from nltk.stem.wordnet import WordNetLemmatizer
from sklearn.feature_extraction.text import TfidfVectorizer
from string import punctuation

def strip_punctuation(s):
    return ''.join(c for c in s if c not in punctuation)

def tokenize_lyrics(s):
    lyrics = s.lower().split()
    lyrics = [word for word in lyrics if word.find('[') == -1]
    lyrics = [word for word in lyrics if word.find(']') == -1]
    lyrics = [strip_punctuation(s) for s in lyrics]
    return lyrics

def lemmatize_word(word):
    wordnet = WordNetLemmatizer()
    lemmatized_word = wordnet.lemmatize(word)
    return lemmatized_word

# def tokenize(doc):
#     return [wordnet.lemmatize(word) for word in nltk.word_tokenize(doc.lower())]

def tokenize(s):
    return [lemmatize_word(word) for word in tokenize_lyrics(s)]

# %%
# create a document of all lyrics to create a vocabulary
all_lyrics = [song['lyrics'] for song in song_list]
all_lyrics_string = ' '.join(all_lyrics)

# %%
# lets take a peak at the total vocabulary
tokenized_vocabulary = tokenize_lyrics(all_lyrics_string)

# %%
count_unique_words = len(set(tokenized_vocabulary))

# %%
count_unique_words
# Out:
# 244984

# %%
# lets take a peak at the total lemmatized vocabulary
lemmatized_vocabulary = [lemmatize_word(word) for word in tokenized_vocabulary]

# %%
count_unique_lem_words = len(set(lemmatized_vocabulary))

# %%
count_unique_lem_words
# Out:
# 233865

# %%
# create a list of all artists and their lyrics
artist_song_list = []
for song in song_list:
    musician_id = song['musician_id']
    song_id = song['_id']
    song_name = song['spotify_track_data']['name']
    musician_name = musician_dev.find_one({'_id': musician_id})['musician_name']
    lyrics = song['lyrics']
    artist_song_list.append((musician_id, musician_name, song_id, song_name, lyrics))

# %%
import pandas as pd
import numpy as np

# %%
# lets create a dataframe of our data
columns = ['musician_id', 'musician_name', 'song_id', 'song_name', 'lyrics']
df = pd.DataFrame.from_records(data=artist_song_list, columns=columns)

# %%
df.head()
# Out:
#                 musician_id musician_name                   song_id  \
# 0  58212da6e228c35b02d5c030          100s  5823c40be228c38897ffa947
# 1  58212da6e228c35b02d5c030          100s  5823c40be228c38897ffa948
# 2  58212da6e228c35b02d5c030          100s  5823c40ce228c38897ffa949
# 3  58212da6e228c35b02d5c030          100s  5823c40ce228c38897ffa94b
# 4  58212da6e228c35b02d5c030          100s  5823c40ce228c38897ffa94c
#
#                    song_name  \
# 0               My Activator
# 1           Brick $ell Phone
# 2                  Slow Drip
# 3          Land of The Laced
# 4  Closer (feat. Mondre MAN)
#
#                                               lyrics
# 0  \n\n"Back up!"\n"Back up, back up, back up..."...
# 1  \n\n[Verse 1]\n(It's that 5th floor...)\n\nTel...
# 2  \n\n[Verse 1]\nAt it again in that le Sabre, m...
# 3  \n\n[Intro]\nCry two tears in a bucket...\nFuc...
# 4  \n\n[Intro: MondreMAN]\nYeah, yeah, Joe S what...

# %%
# create a dataframe of just artists and their lyrics
lyrics_by_artist_series = df[['musician_name','lyrics']].groupby('musician_name')['lyrics'].apply(lambda x: ' '.join(x))

# %%
# lets take a peak
lyrics_by_artist_df = pd.Series.to_frame(lyrics_by_artist_series)
lyrics_by_artist_df.reset_index(inplace=True)
lyrics_by_artist_df.head()
# Out:
#      musician_name                                             lyrics
# 0             100s  \n\n"Back up!"\n"Back up, back up, back up..."...
# 1              112  \n\n[Slim (Foxy Brown]\nUh, 112 (Foxy)\nUh, (1...
# 2  1200 Techniques  \n\n[DJ Peril]\nNfamous - step, step, step, st...
# 3         2 Chainz  \n\n[Intro]\nCheck me out now\n\n[Hook]\nYeah,...
# 4      2 Live Crew  \n\n( ) = Mixx's lines during verses\n\nIntro:...

# %%
len(lyrics_by_artist_df)
# Out:
# 1112

# %%
# the moment we've all been waiting for lets vectorize this bad boy!

# %%
vectorizer = TfidfVectorizer(stop_words='english', tokenizer=tokenize)
vectors = vectorizer.fit_transform(lyrics_by_artist_df['lyrics']).toarray()

# %%
feature_words = vectorizer.get_feature_names()

# %%
feature_words[500:1500]
# Out:
# [u'30003000',
#  u'3000s',
#  u'3001',
#  u'300g',
#  u'300k',
#  u'301',
#  u'3030',
#  u'303rd',
#  u'304',
#  u'304s',
#  u'305',
#  u'305s',
#  u'30k',
#  u'30round',
#  u'30something',
#  u'30th',
#  u'30year',
#  u'30years',
#  u'30\u2019s',
#  u'31',
#  u'310',
#  u'311',
#  u'312',
#  u'31276210',
#  u'313',
#  u'313s',
#  u'314',
#  u'31558464000',
#  u'316',
#  u'31s',
#  u'31st',
#  u'32',
#  u'320',
#  u'321',
#  u'321456',
#  u'322',
#  u'323',
#  u'324',
#  u'325',
#  u'33',
#  u'330',
#  u'330055',
#  u'336',
#  u'34',
#  u'342036',
#  u'34th',
#  u'34ths',
#  u'35',
#  u'350',
#  u'35000',
#  u'350you',
#  u'355',
#  u'357',
#  u'35hundred',
#  u'35th',
#  u'35ths',
#  u'36',
#  u'360',
#  u'362436',
#  u'365',
#  u'365\u306e\u65e5\u5e38',
#  u'36th',
#  u'37',
#  u'38',
#  u'380',
#  u'380s',
#  u'382437',
#  u'38s',
#  u'38th',
#  u'38\u2019s',
#  u'39',
#  u'390',
#  u'399',
#  u'3999',
#  u'3a',
#  u'3am',
#  u'3big',
#  u'3celph',
#  u'3d',
#  u'3d2',
#  u'3do',
#  u'3doap',
#  u'3e',
#  u'3g',
#  u'3hree',
#  u'3hundred',
#  u'3hunna',
#  u'3inch',
#  u'3j52',
#  u'3jamie',
#  u'3k',
#  u'3krazy',
#  u'3nate',
#  u'3o',
#  u'3one',
#  u'3p',
#  u'3pack',
#  u'3point',
#  u'3pointer',
#  u'3rail',
#  u'3rd',
#  u'3vinnie',
#  u'3way',
#  u'3wheel',
#  u'3will',
#  u'3x',
#  u'3xmic',
#  u'3xzibit',
#  u'3year',
#  u'3\xe8me',
#  u'3\u2013',
#  u'4',
#  u'40',
#  u'400',
#  u'4000',
#  u'400s',
#  u'401ks',
#  u'4026',
#  u'403',
#  u'405',
#  u'40bottle',
#  u'40cal',
#  u'40dog',
#  u'40glock',
#  u'40i',
#  u'40k',
#  u'40ounce',
#  u'40ounces',
#  u'40pound',
#  u'40th',
#  u'40z',
#  u'40\u2019s',
#  u'40\uc778\uc758',
#  u'41',
#  u'410s',
#  u'411',
#  u'412',
#  u'4129\u2026',
#  u'412s',
#  u'414',
#  u'415',
#  u'415s',
#  u'4180',
#  u'41st',
#  u'42',
#  u'420',
#  u'4200',
#  u'424',
#  u'426',
#  u'427',
#  u'43',
#  u'430',
#  u'432',
#  u'44',
#  u'440',
#  u'442',
#  u'4433069762',
#  u'44s',
#  u'44z',
#  u'44\u2032s',
#  u'45',
#  u'450',
#  u'454',
#  u'454s',
#  u'455',
#  u'456ing',
#  u'458',
#  u'459',
#  u'45k',
#  u'45s',
#  u'45th',
#  u'45\u2019s',
#  u'46',
#  u'47',
#  u'470',
#  u'47th',
#  u'48',
#  u'4888',
#  u'48track',
#  u'49',
#  u'490',
#  u'499',
#  u'49999',
#  u'49er',
#  u'49ers',
#  u'4am',
#  u'4by4',
#  u'4door',
#  u'4g',
#  u'4get',
#  u'4hunnid',
#  u'4ize',
#  u'4k',
#  u'4kurupt',
#  u'4one',
#  u'4pac',
#  u'4play',
#  u'4r',
#  u'4rom',
#  u'4runner',
#  u'4supa',
#  u'4tay',
#  u'4th',
#  u'4track',
#  u'4way',
#  u'4wheel',
#  u'4winners',
#  u'4x',
#  u'4xs',
#  u'4you',
#  u'4z',
#  u'5',
#  u'50',
#  u'500',
#  u'5000',
#  u'50000',
#  u'500000',
#  u'5000crack',
#  u'500k',
#  u'500sel',
#  u'501',
#  u'50100s',
#  u'501s',
#  u'502',
#  u'504',
#  u'505',
#  u'5050',
#  u'50a',
#  u'50inch',
#  u'50k',
#  u'50shot',
#  u'50th',
#  u'50yard',
#  u'50yearold',
#  u'50\u2019s',
#  u'51',
#  u'510',
#  u'514',
#  u'515',
#  u'5150',
#  u'516',
#  u'517',
#  u'52',
#  u'520',
#  u'522',
#  u'524',
#  u'525',
#  u'526',
#  u'5272562',
#  u'52nd',
#  u'53',
#  u'5316852',
#  u'54',
#  u'5411',
#  u'5432',
#  u'546',
#  u'549',
#  u'55',
#  u'550',
#  u'550s',
#  u'55405',
#  u'555',
#  u'559',
#  u'56',
#  u'56k',
#  u'57',
#  u'58',
#  u'580',
#  u'59',
#  u'5900',
#  u'5965',
#  u'599',
#  u'5am',
#  u'5amja',
#  u'5d',
#  u'5ed',
#  u'5ers',
#  u'5foot',
#  u'5foot8',
#  u'5in',
#  u'5k1',
#  u'5north',
#  u'5o',
#  u'5o\u2019clock',
#  u'5star',
#  u'5th',
#  u'5trey',
#  u'5x',
#  u'5\u201911\u201d',
#  u'5\u2019s',
#  u'6',
#  u'60',
#  u'600',
#  u'6000',
#  u'6040',
#  u'604am',
#  u'60644',
#  u'61',
#  u'612',
#  u'6129779870',
#  u'6129779871',
#  u'615',
#  u'61st',
#  u'62',
#  u'6219999',
#  u'626',
#  u'62s',
#  u'63',
#  u'630',
#  u'635',
#  u'63rd',
#  u'64',
#  u'646',
#  u'64s',
#  u'64th',
#  u'65',
#  u'650',
#  u'65000',
#  u'66',
#  u'666',
#  u'67',
#  u'675',
#  u'679',
#  u'68',
#  u'69',
#  u'6996',
#  u'69an',
#  u'69and',
#  u'69cause',
#  u'69here',
#  u'69ing',
#  u'69now',
#  u'69s',
#  u'69sit',
#  u'69true',
#  u'69you',
#  u'6am',
#  u'6big',
#  u'6double6',
#  u'6foot',
#  u'6ix',
#  u'6man',
#  u'6pack',
#  u'6pm',
#  u'6th',
#  u'6tre',
#  u'6x',
#  u'6x9s',
#  u'6\xe9me',
#  u'6\u20194\u201d',
#  u'6\u2019s',
#  u'7',
#  u'70',
#  u'700',
#  u'702',
#  u'7030',
#  u'707',
#  u'71',
#  u'710',
#  u'711',
#  u'711s',
#  u'713',
#  u'71717171',
#  u'718',
#  u'72',
#  u'720',
#  u'73',
#  u'730',
#  u'73s',
#  u'74',
#  u'740',
#  u'745',
#  u'745s',
#  u'747s',
#  u'74fizzive',
#  u'75',
#  u'750',
#  u'76',
#  u'760',
#  u'762s',
#  u'762\u2019s',
#  u'77',
#  u'7779311',
#  u'78',
#  u'780',
#  u'789',
#  u'79',
#  u'7ccs',
#  u'7d',
#  u'7ds',
#  u'7duce',
#  u'7eleven',
#  u'7even',
#  u'7l',
#  u'7o',
#  u'7ods',
#  u'7th',
#  u'7up',
#  u'7x',
#  u'7yearold',
#  u'7\xe8me',
#  u'7\uc2dc',
#  u'8',
#  u'80',
#  u'800',
#  u'80000',
#  u'803',
#  u'8043350051',
#  u'8043350051gucci',
#  u'807',
#  u'808',
#  u'808s',
#  u'808\u2019s',
#  u'80\u2019s',
#  u'81',
#  u'813',
#  u'815s',
#  u'816',
#  u'818',
#  u'818s',
#  u'82',
#  u'83',
#  u'830',
#  u'833',
#  u'83s',
#  u'84',
#  u'842',
#  u'84s',
#  u'84th',
#  u'85',
#  u'850',
#  u'85er',
#  u'85ers',
#  u'85ersand',
#  u'85th',
#  u'86',
#  u'860',
#  u'8612730112',
#  u'868',
#  u'86ed',
#  u'87',
#  u'876',
#  u'87th',
#  u'88',
#  u'8804',
#  u'885',
#  u'88s',
#  u'88th',
#  u'88\ub144\ub3c4',
#  u'89',
#  u'8990',
#  u'8ball',
#  u'8bit',
#  u'8hour',
#  u'8k',
#  u'8pm',
#  u'8th',
#  u'8ths',
#  u'8track',
#  u'8x',
#  u'8\u2019s',
#  u'8\uc2dc',
#  u'8\uc6d4',
#  u'9',
#  u'90',
#  u'900',
#  u'9000',
#  u'90000',
#  u'90059',
#  u'9010',
#  u'908',
#  u'909',
#  u'90951',
#  u'90now',
#  u'90\u2019s',
#  u'91',
#  u'910',
#  u'911',
#  u'911s',
#  u'91282',
#  u'915',
#  u'917',
#  u'919',
#  u'92',
#  u'921',
#  u'9215318328',
#  u'922',
#  u'923',
#  u'92782',
#  u'92i',
#  u'92izi',
#  u'92s',
#  u'93',
#  u'930',
#  u'94',
#  u'95',
#  u'9500',
#  u'9596',
#  u'96',
#  u'97',
#  u'971',
#  u'976bun',
#  u'98',
#  u'987654321',
#  u'98def',
#  u'98s',
#  u'99',
#  u'99400',
#  u'995',
#  u'999',
#  u'999000',
#  u'999899',
#  u'99s',
#  u'9fevaroo',
#  u'9fever',
#  u'9foot',
#  u'9live',
#  u'9mil',
#  u'9mm',
#  u'9months',
#  u'9nickel',
#  u'9o',
#  u'9th',
#  u'9ths',
#  u'9to5',
#  u'9to5ll',
#  u'9x',
#  u'9yearold',
#  u'9z',
#  u'9\u2019s',
#  u'9\u2032s',
#  u'a1',
#  u'a1a',
#  u'a1s',
#  u'a3oudoubillah',
#  u'a7',
#  u'a8',
#  u'a8s',
#  u'aa',
#  u'aaa',
#  u'aaaa',
#  u'aaaaaaa',
#  u'aaaaaaaaaaaaaaahhhhhhhhhhhhhhhh',
#  u'aaaaaaaalchemist',
#  u'aaaaaaahh',
#  u'aaaaaaahhhhhhhhhhhh',
#  u'aaaaaaall',
#  u'aaaaaaasasarock',
#  u'aaaaaah',
#  u'aaaaaghhh',
#  u'aaaaah',
#  u'aaaaahhhhh',
#  u'aaaah',
#  u'aaaahhaa',
#  u'aaaahhh',
#  u'aaaahhhh',
#  u'aaaaja',
#  u'aaaaoooowwww',
#  u'aaaawwwhhh',
#  u'aaafro',
#  u'aaah',
#  u'aaahh',
#  u'aaahhh',
#  u'aaahhhh',
#  u'aaah\u2026',
#  u'aaay',
#  u'aaayye',
#  u'aadmi',
#  u'aaey',
#  u'aah',
#  u'aaha',
#  u'aahooh',
#  u'aahs',
#  u'aai',
#  u'aair',
#  u'aaja',
#  u'aal',
#  u'aale',
#  u'aali',
#  u'aalike',
#  u'aalikes',
#  u'aaliyah',
#  u'aaliyahs',
#  u'aall',
#  u'aalto',
#  u'aam',
#  u'aamber',
#  u'aamco',
#  u'aamul',
#  u'aamulehden',
#  u'aamulla',
#  u'aamun',
#  u'aan',
#  u'aand',
#  u'aangesneld',
#  u'aankeek',
#  u'aanpassen',
#  u'aantrekkelijk',
#  u'aap',
#  u'aapa',
#  u'aar',
#  u'aarab',
#  u'aarde',
#  u'aaron',
#  u'aas',
#  u'aassination',
#  u'aatrocious',
#  u'aaww',
#  u'aayyeah',
#  u'aayyeee',
#  u'ab',
#  u'aba',
#  u'aback',
#  u'abacus',
#  u'abade',
#  u'abaixo',
#  u'abajo',
#  u'abakwana',
#  u'abaloneya',
#  u'abandon',
#  u'abandonaste',
#  u'abandoned',
#  u'abandonin',
#  u'abandonment',
#  u'abandonn\xe9',
#  u'abandono',
#  u'abani',
#  u'abarcan',
#  u'abarco',
#  u'abashed',
#  u'abate',
#  u'abates',
#  u'abats',
#  u'abattre',
#  u'abattu',
#  u'abay',
#  u'abaybay',
#  u'abba',
#  u'abbai',
#  u'abbandona',
#  u'abbandoni',
#  u'abbassa',
#  u'abbassano',
#  u'abbasso',
#  u'abbastanza',
#  u'abbazabba',
#  u'abbess',
#  u'abbey',
#  u'abbia',
#  u'abbiamo',
#  u'abbigliamento',
#  u'abboccare',
#  u'abbot',
#  u'abbott',
#  u'abbracci',
#  u'abbraccia',
#  u'abbracciati',
#  u'abbraccio',
#  u'abbreviation',
#  u'abbronzare',
#  u'abbronzati',
#  u'abbronzatura',
#  u'abbusive',
#  u'abby',
#  u'abc',
#  u'abcalike',
#  u'abcdefg',
#  u'abcdegh',
#  u'abcdfill',
#  u'abcgesch\xfctzen',
#  u'abcsch\xfctze',
#  u'abcsee',
#  u'abd',
#  u'abdah',
#  u'abdel',
#  u'abdelhamid',
#  u'abdish',
#  u'abdomen',
#  u'abdominal',
#  u'abduct',
#  u'abducted',
#  u'abduction',
#  u'abductor',
#  u'abdul',
#  u'abe',
#  u'abecean',
#  u'abed',
#  u'abednego',
#  u'abel',
#  u'abelibabeli',
#  u'abend',
#  u'abendbrot',
#  u'abende',
#  u'abends',
#  u'aber',
#  u'abercrombie',
#  u'abernathy',
#  u'abf\xe4lliger',
#  u'abgebrannt',
#  u'abgemacht',
#  u'abgesahnt',
#  u'abgesehen',
#  u'abhaya',
#  u'abhi',
#  u'abholen',
#  u'abh\xe4ngt',
#  u'abh\xf6rn',
#  u'abi',
#  u'abide',
#  u'abidin',
#  u'abiding',
#  u'ability',
#  u'abir',
#  u'abitacion',
#  u'abitch',
#  u'abiti',
#  u'abito',
#  u'abituati',
#  u'abiye',
#  u'abjecte',
#  u'abk',
#  u'ablaze',
#  u'able',
#  u'ablehnen',
#  u'ablend',
#  u'ablers',
#  u'ablitz',
#  u'abmix',
#  u'abmi\xdft',
#  u'abmur',
#  u'abnorm',
#  u'abnormal',
#  u'aboard',
#  u'abode',
#  u'abogado',
#  u'abogao',
#  u'aboies',
#  u'abois',
#  u'aboki',
#  u'abokis',
#  u'abolish',
#  u'abolition',
#  u'abominable',
#  u'abomination',
#  u'abonn\xe9es',
#  u'aboout',
#  u'aboriginal',
#  u'aborigine',
#  u'abort',
#  u'aborted',
#  u'aborting',
#  u'abortion',
#  u'abot',
#  u'abound',
#  u'abouthis',
#  u'aboutll',
#  u'abouts',
#  u'aboutyo',
#  u'about\u201d',
#  u'aboveuh',
#  u'abpfiff',
#  u'abracadabra',
#  u'abracadabrah',
#  u'abradab',
#  u'abrae',
#  u'abrah',
#  u'abraham',
#  u'abrakadaba',
#  u'abramson',
#  u'abrasive',
#  u'abraso',
#  u'abrazado',
#  u'abrazes',
#  u'abrazos',
#  u'abreast',
#  u'abreuvoir',
#  u'abriendo',
#  u'abrigou',
#  u'abrir',
#  u'abrirse',
#  u'abrissparty',
#  u'abrite',
#  u'abri\xe9ndose',
#  u'abro',
#  u'abroad',
#  u'abrupt',
#  u'abruptly',
#  u'absauf',
#  u'abschiedskuss',
#  u'abschluss',
#  u'abschotten',
#  u'abseits',
#  u'absence',
#  u'absenceuntil',
#  u'absent',
#  u'absentminded',
#  u'absinth',
#  u'absinthe',
#  u'absolut',
#  u'absolute',
#  u'absolutely',
#  u'absoluter',
#  u'absolution',
#  u'absoluut',
#  u'absolved',
#  u'absorb',
#  u'absorbed',
#  u'absorbem',
#  u'absorbing',
#  u'absorbs',
#  u'absoul',
#  u'absouls',
#  u'abstain',
#  u'abstellgleis',
#  u'abstinance',
#  u'abstinence',
#  u'abstinent',
#  u'abstract',
#  u'abstractionism',
#  u'abstracto',
#  u'absturz',
#  u'absurd',
#  u'absurdo',
#  u'absurdos',
#  u'abt',
#  u'abteilung',
#  u'abu',
#  u'abuelo',
#  u'abujamal',
#  u'abulances',
#  u'abundance',
#  u'abundant',
#  u'aburo',
#  u'aburre',
#  u'aburrida',
#  u'aburridos',
#  u'abus',
#  u'abuse',
#  u'abused',
#  u'abuser',
#  u'abusin',
#  u'abusing',
#  u'abusive',
#  u'abuso',
#  u'abusos',
#  u'abusosudo',
#  u'abus\xe9',
#  u'aby',
#  u'abysmal',
#  u'abyss',
#  u'abyssale',
#  u'abyssinia',
#  u'abzuchecken',
#  u'abzuderben',
#  u'abzuhauen',
#  u'ac',
#  u'aca',
#  u'acaba',
#  u'acabados',
#  u'acaban',
#  u'acabando',
#  u'acabao',
#  u'acabar',
#  u'acabar\xe1',
#  u'acabar\xe9',
#  u'acabe',
#  u'acabo',
#  u'acacia',
#  u'academia',
#  u'academic',
#  u'academy',
#  u'acapell',
#  u'acapella',
#  u'acapellas',
#  u'acapello',
#  u'acappella',
#  u'acappellas',
#  u'acapulco',
#  u'acariciarla',
#  u'acariciarnos',
#  u'acaricio',
#  u'acaso',
#  u'acates',
#  u'acc',
#  u'accabl\xe9',
#  u'accanito',
#  u'accanto',
#  u'accapella',
#  u'accappellas',
#  u'accarezza',
#  u'accarezzarti',
#  u'accatt\xe0',
#  u'accecate',
#  u'accedo',
#  u'accelerate',
#  u'accelerated',
#  u'acceleration',
#  u'accelerator',
#  u'accelero',
#  u'accendi',
#  u'accendino',
#  u'accendo',
#  u'accendono',
#  u'accensione',
#  u'accent',
#  u'accented',
#  u'accept',
#  u'acceptability',
#  u'acceptable',
#  u'acceptance',
#  u'accepted',
#  u'acceptent',
#  u'accepter',
#  u'acceptin',
#  u'accepting',
#  u'acceptons',
#  u'accepts',
#  u'accesa',
#  u'accese',
#  u'acceso',
#  u'accesories',
#  u'access',
#  u'accessible',
#  u'accessive',
#  u'accessori',
#  u'accessory',
#  u'accettare',
#  u'accetto',
#  u'acchieve',
#  u'accident',
#  u'accidental',
#  u'accidentally',
#  u'accidently',
#  u'accion',
#  u'acci\xf3n',
#  u'acclaim',
#  u'acclaimed',
#  u'acclimation',
#  u'accolade',
#  u'accomidate',
#  u'accommadating',
#  u'accommodate',
#  u'accommodated',
#  u'accomodate',
#  u'accomodations',
#  u'accompagnent',
#  u'accompagner',
#  u'accompagn\xe9s',
#  u'accompanied',
#  u'accompli',
#  u'accomplice',
#  u'accomplir',
#  u'accomplish',
#  u'accomplished',
#  u'accomplishing',
#  u'accomplishment',
#  u'accomplishs',
#  u'accontentarci',
#  u'accord',
#  u'accorde',
#  u'accordin',
#  u'according',
#  u'accordingly',
#  u'accordion',
#  u'accordly',
#  u'accorgi',
#  u'accorto',
#  u'accosted',
#  u'accoud\xe9',
#  u'accoud\xe9s',
#  u'account',
#  u'accountable',
#  u'accountant',
#  u'accounted',
#  u'accounting',
#  u'accountmothafucka',
#  u'accoustics',
#  u'accoutrement',
#  u'accrochent',
#  u'accroch\xe9',
#  u'accroupi',
#  u'accroupies',
#  u'acctually',
#  u'accueille',
#  u'accumulate',
#  u'accumulated',
#  u'accumulates',
#  u'accumulating',
#  u'accumuli',
#  u'accumulo',
#  u'accupressure',
#  u'accupuncture',
#  u'accura',
#  u'accuracy',
#  u'accurate',
#  u'accurately',
#  u'accusation',
#  u'accuse',
#  u'accused',
#  u'accuseranno']

# %%
# so we can see a bunch of mispellings. Not sure if we can attribute this to the musician or
# to where ever / whomever genius gets their lyrics from
# there is a risk our dimensionality reduction could mearly discover these "bad" sources as
# a hidden feature

# %% [markdown]
# # FSM - Modeling

# %%
# Let's try NMF then LDA

from sklearn.decomposition import NMF
n_topics = 30

def reconst_mse(target, left, right):
    return (np.array(target - left.dot(right))**2).mean()

def describe_nmf_results(document_term_mat, W, H, n_top_words = 15):
    print("Reconstruction error: %f") %(reconst_mse(document_term_mat, W, H))
    for topic_num, topic in enumerate(H):
        print("Topic %d:" % topic_num)
        print(" ".join([feature_words[i] \
                for i in topic.argsort()[:-n_top_words - 1:-1]]))

# %%
nmf = NMF(n_components=n_topics)
W_sklearn = nmf.fit_transform(vectors)
H_sklearn = nmf.components_
describe_nmf_results(vectors, W_sklearn, H_sklearn)
# Out:
# Reconstruction error: 0.000003
# Topic 0:
# im dont just thats aint cause like ive ill feel think better imma time need
# Topic 1:
# nigga fuck shit bitch aint know im gon money em dont real young bout make
# Topic 2:
# le à je et dans que pa qui la cest est comme en mais tu
# Topic 3:
# girl love baby wanna oh let want know just make hey time come youre like
# Topic 4:
# i’m don’t it’s ain’t like that’s just know can’t i’ll you’re ‘em say tell i’ve
# Topic 5:
# got money im aint like man just girl young trap tryna shit gotta new cash
# Topic 6:
# que y en el mi te tu por lo se la para como e los
# Topic 7:
# like know im make ya beat flow  rap style hit wa new got car
# Topic 8:
# und ich ist der nicht wir du wie auf sie mit zu für die ein
# Topic 9:
# je se za sve da ne sam ja kad na mi ko smo samo ti
# Topic 10:
# bitch hoe lil pussy dick imma ho fuck like money aint yo know dont bad
# Topic 11:
# 난 내 내가 다 날 넌 이 더 나의 수 또 안 나는 그 니
# Topic 12:
# yo yall im shit got wit ya man street thats rap black uh wa aint
# Topic 13:
# cause rhyme im mc youre dont funky mic yo rock come got brother time man
# Topic 14:
# yeah oh mmm just hmmm know like im everybody uh decatur em hell tell feel
# Topic 15:
# la got hey gangsta jump oh dont milf youre blasé zaccka thuggin badman glamorous like
# Topic 16:
# che il è e non di sono io mi se una la più quando ci
# Topic 17:
# na dey eh ni o wo nwa oya asa yeh nie baby e obianuju kukere
# Topic 18:
#  im uh ya aint ta like dont yall come booty 2x beat 0 chigga
# Topic 19:
# life time u make god love day just mind world people soul eye youre black
# Topic 20:
# fuck shit bitch fucking dick motherfucker dont got like fuckin cause just kill fucked gun
# Topic 21:
# wa just said man cause aint say thought like really good got didnt know knew
# Topic 22:
# im ya got gangsta cause aint nigga wit dogg g chorus game dont fool wanna
# Topic 23:
# im big boy cause know got aint like hoe moe trunk playa ya ima mayn
# Topic 24:
# bmi ascap produced music publishing published additional recorded studio llc written j mixed featuring adm
# Topic 25:
# em let like ya make air dont clap drop fall hit hand 3x u say
# Topic 26:
# dem mi di gyal yuh vibe hotta nuh inna bad fi seh ting gal say
# Topic 27:
# feat prod monty  ft love tracklist ayy themind know 14 7 2 11 im
# Topic 28:
# da dat wit law ya break bay ay palmdale betta tha yo dont wanna ba
# Topic 29:
# know dont aint like just tell wanna thats want say man let come cause way

# %%
# I found out we have some musicians from different languages I need to take into account
# Based on this realization and advise from instructors, I'll adjust my project
# to only focus on Musicians who only speak english

# %%
musician_dev.find_one({})['spotify_data']['genres']
# Out:
# [u'bulgarian rock', u'chalga']

# %%
musicians = [musician for musician in musician_dev.find({'spotify_data': {'$exists': True, '$nin': ['No Results']}})]

# %%
genres = [musician['spotify_data']['genres'] for musician in musicians]

# %%
genres
# Out:
# [[u'bulgarian rock', u'chalga'],
#  [u'j-dance', u'j-indie', u'j-rock', u'underground hip hop'],
#  [],
#  [u'pop rap', u'rap', u'southern hip hop', u'trap music'],
#  [u'crunk',
#   u'dirty south rap',
#   u'gangster rap',
#   u'hip pop',
#   u'pop rap',
#   u'rap',
#   u'southern hip hop',
#   u'trap music'],
#  [],
#  [u'dwn trap', u'trap music'],
#  [u'abstract hip hop', u'underground rap'],
#  [u'deep regional mexican'],
#  [u'gangster rap', u'hyphy', u'pop rap'],
#  [u'crunk',
#   u'dance pop',
#   u'dirty south rap',
#   u'east coast hip hop',
#   u'gangster rap',
#   u'hip hop',
#   u'hip pop',
#   u'pop rap',
#   u'rap',
#   u'trap music'],
#  [],
#  [],
#  [u'alternative hip hop', u'hip hop'],
#  [],
#  [],
#  [u'alternative hip hop',
#   u'escape room',
#   u'hip hop',
#   u'indie r&b',
#   u'pop rap',
#   u'rap',
#   u'southern hip hop',
#   u'trap music',
#   u'underground hip hop'],
#  [u'abstract hip hop', u'underground rap'],
#  [u'crunk',
#   u'dirty south rap',
#   u'gangster rap',
#   u'hip hop',
#   u'pop rap',
#   u'rap',
#   u'southern hip hop',
#   u'trap music'],
#  [u'abstract hip hop',
#   u'alternative hip hop',
#   u'hip hop',
#   u'turntablism',
#   u'underground rap'],
#  [u'alternative hip hop',
#   u'east coast hip hop',
#   u'rap',
#   u'underground hip hop'],
#  [],
#  [u'abstract hip hop',
#   u'alternative hip hop',
#   u'dirty south rap',
#   u'hardcore hip hop',
#   u'hip hop',
#   u'pop rap',
#   u'turntablism'],
#  [u'east coast hip hop',
#   u'electro',
#   u'freestyle',
#   u'funk',
#   u'gangster rap',
#   u'hardcore hip hop',
#   u'hip hop',
#   u'miami bass',
#   u'old school hip hop',
#   u'rap',
#   u'turntablism'],
#  [u'crunk',
#   u'dirty south rap',
#   u'gangster rap',
#   u'hip hop',
#   u'pop christmas',
#   u'pop rap',
#   u'rap',
#   u'southern hip hop'],
#  [u'alternative hip hop',
#   u'east coast hip hop',
#   u'hardcore hip hop',
#   u'hip hop',
#   u'turntablism'],
#  [u'hardcore hip hop'],
#  [u'bebop',
#   u'contemporary post-bop',
#   u'cool jazz',
#   u'hard bop',
#   u'jazz',
#   u'jazz blues',
#   u'jazz funk',
#   u'jazz fusion',
#   u'soul jazz',
#   u'stride'],
#  [u'yugoslav rock'],
#  [u'grime', u'uk garage'],
#  [u'east coast hip hop',
#   u'gangster rap',
#   u'hardcore hip hop',
#   u'hip hop',
#   u'hip pop'],
#  [u'flick hop', u'underground rap'],
#  [u'dance pop',
#   u'dirty south rap',
#   u'hip hop',
#   u'hip pop',
#   u'pop',
#   u'pop rap',
#   u'r&b',
#   u'rap',
#   u'southern hip hop',
#   u'urban contemporary'],
#  [u'alternative hip hop',
#   u'hardcore hip hop',
#   u'hip hop',
#   u'southern hip hop',
#   u'turntablism',
#   u'west coast rap'],
#  [],
#  [u'classical',
#   u'classical christmas',
#   u'classical performance',
#   u'classical period'],
#  [u'gangster rap'],
#  [u'hip pop'],
#  [u'hyphy'],
#  [u'escape room', u'indie r&b', u'la indie'],
#  [u'alternative hip hop',
#   u'dirty south rap',
#   u'hip hop',
#   u'neo soul',
#   u'pop rap',
#   u'rap',
#   u'southern hip hop'],
#  [u'dirty south rap', u'gangster rap', u'hyphy', u'west coast rap'],
#  [u'christian hip hop'],
#  [u'escape room', u'hip pop', u'indie r&b'],
#  [u'hip pop', u'pop rap', u'r&b', u'urban contemporary'],
#  [u'drill'],
#  [u'g funk', u'gangster rap', u'hyphy', u'west coast rap'],
#  [u'deep talent show'],
#  [],
#  [u'cumbia', u'cumbia sonidera', u'grupera'],
#  [],
#  [],
#  [u'hip hop', u'pop rap', u'rap', u'southern hip hop', u'trap music'],
#  [],
#  [u'east coast hip hop',
#   u'pop rap',
#   u'rap',
#   u'southern hip hop',
#   u'trap music'],
#  [],
#  [u'dirty south rap',
#   u'hip hop',
#   u'pop rap',
#   u'rap',
#   u'southern hip hop',
#   u'trap music',
#   u'underground pop rap'],
#  [u'abstract hip hop', u'underground rap'],
#  [u'abstract hip hop', u'underground rap'],
#  [u'escape room', u'hip pop'],
#  [u'alternative hip hop',
#   u'gangster rap',
#   u'hardcore hip hop',
#   u'hip hop',
#   u'rap',
#   u'southern hip hop'],
#  [u'bmore',
#   u'dance pop',
#   u'escape room',
#   u'hip house',
#   u'hip pop',
#   u'indie r&b',
#   u'pop',
#   u'pop rap'],
#  [u'g funk', u'hyphy', u'west coast rap'],
#  [u'chicano rap',
#   u'gangster rap',
#   u'hardcore hip hop',
#   u'hip hop',
#   u'rap',
#   u'west coast rap'],
#  [u'crunk',
#   u'dirty south rap',
#   u'gangster rap',
#   u'memphis hip hop',
#   u'pop rap',
#   u'rap',
#   u'southern hip hop',
#   u'trap music'],
#  [u'deep g funk', u'g funk', u'west coast rap'],
#  [u'crunk',
#   u'dance pop',
#   u'dirty south rap',
#   u'gangster rap',
#   u'hip hop',
#   u'pop',
#   u'pop rap',
#   u'rap',
#   u'southern hip hop',
#   u'trap music'],
#  [u'chicano rap',
#   u'crunk',
#   u'dance pop',
#   u'dirty south rap',
#   u'gangster rap',
#   u'hip hop',
#   u'hip pop',
#   u'latin hip hop',
#   u'pop rap',
#   u'r&b',
#   u'rap',
#   u'southern hip hop',
#   u'trap music',
#   u'urban contemporary'],
#  [u'crunk',
#   u'dirty south rap',
#   u'gangster rap',
#   u'pop rap',
#   u'rap',
#   u'southern hip hop',
#   u'trap music'],
#  [],
#  [],
#  [],
#  [u'deep pop r&b', u'trap music'],
#  [u'alternative hip hop', u'hardcore hip hop', u'hip hop', u'turntablism'],
#  [],
#  [],
#  [u'underground hip hop'],
#  [u'deep g funk', u'hyphy'],
#  [u'crunk',
#   u'dirty south rap',
#   u'east coast hip hop',
#   u'gangster rap',
#   u'hardcore hip hop',
#   u'hip hop',
#   u'hip pop',
#   u'pop rap',
#   u'rap',
#   u'southern hip hop'],
#  [u'dance pop', u'pop', u'post-teen pop'],
#  [],
#  [u'crunk',
#   u'dirty south rap',
#   u'gangster rap',
#   u'hardcore hip hop',
#   u'hip hop',
#   u'hip pop',
#   u'pop rap',
#   u'rap',
#   u'southern hip hop'],
#  [u'alternative hip hop',
#   u'crunk',
#   u'dirty south rap',
#   u'gangster rap',
#   u'hardcore hip hop',
#   u'hip hop',
#   u'pop rap',
#   u'rap',
#   u'southern hip hop',
#   u'trap music'],
#  [u'alternative hip hop',
#   u'east coast hip hop',
#   u'gangster rap',
#   u'hardcore hip hop',
#   u'hip hop',
#   u'hip pop',
#   u'old school hip hop',
#   u'rap',
#   u'turntablism'],
#  [u'memphis hip hop'],
#  [u'dirty south rap', u'southern hip hop'],
#  [],
#  [u'dirty south rap',
#   u'hip hop',
#   u'pop rap',
#   u'rap',
#   u'southern hip hop',
#   u'trap music',
#   u'underground hip hop'],
#  [u'crunk',
#   u'deep trap',
#   u'dirty south rap',
#   u'gangster rap',
#   u'memphis hip hop',
#   u'pop rap',
#   u'rap',
#   u'southern hip hop',
#   u'trap music'],
#  [u'dirty texas rap', u'hyphy', u'memphis hip hop'],
#  [u'alternative hip hop',
#   u'east coast hip hop',
#   u'gangster rap',
#   u'hardcore hip hop',
#   u'hip hop',
#   u'rap',
#   u'turntablism'],
#  [u'dirty south rap', u'dirty texas rap', u'memphis hip hop'],
#  [],
#  [u'crunk',
#   u'dirty south rap',
#   u'gangster rap',
#   u'memphis hip hop',
#   u'southern hip hop',
#   u'trap music'],
#  [u'hardcore hip hop'],
#  [u'dirty south rap', u'dirty texas rap', u'memphis hip hop'],
#  [u'alternative hip hop'],
#  [u'crunk',
#   u'dirty south rap',
#   u'east coast hip hop',
#   u'gangster rap',
#   u'hardcore hip hop',
#   u'hip hop',
#   u'hip pop',
#   u'pop rap',
#   u'rap',
#   u'southern hip hop'],
#  [],
#  [],
#  [u'detroit hip hop', u'pop rap', u'rap', u'southern hip hop', u'trap music'],
#  [u'hardcore hip hop', u'turntablism'],
#  [u'g funk', u'gangster rap', u'hyphy', u'west coast rap'],
#  [],
#  [u'abstract hip hop', u'alternative hip hop'],
#  [u'crunk',
#   u'dirty south rap',
#   u'gangster rap',
#   u'hip hop',
#   u'hip pop',
#   u'pop rap',
#   u'rap',
#   u'southern hip hop',
#   u'trap music'],
#  [u'escape room', u'underground hip hop'],
#  [u'east coast hip hop',
#   u'gangster rap',
#   u'hardcore hip hop',
#   u'hip hop',
#   u'old school hip hop',
#   u'rap'],
#  [u'detroit hip hop'],
#  [u'chicano rap',
#   u'crunk',
#   u'dirty south rap',
#   u'gangster rap',
#   u'hardcore hip hop',
#   u'hip hop',
#   u'hyphy',
#   u'pop rap',
#   u'southern hip hop'],
#  [u'indie r&b', u'rap'],
#  [u'alternative hip hop', u'detroit hip hop', u'hip hop'],
#  [u'dirty south rap',
#   u'gangster rap',
#   u'hardcore hip hop',
#   u'hip hop',
#   u'hip pop',
#   u'southern hip hop'],
#  [u'alternative hip hop',
#   u'east coast hip hop',
#   u'hardcore hip hop',
#   u'hip hop'],
#  [],
#  [u'flick hop', u'hardcore hip hop', u'underground rap'],
#  [u'horrorcore'],
#  [u'crunk',
#   u'deep trap',
#   u'dirty south rap',
#   u'gangster rap',
#   u'memphis hip hop',
#   u'pop rap',
#   u'rap',
#   u'southern hip hop',
#   u'trap music'],
#  [u'dance pop',
#   u'hip pop',
#   u'neo soul',
#   u'new jack swing',
#   u'pop rap',
#   u'r&b',
#   u'urban contemporary'],
#  [],
#  [u'pop rap', u'rap', u'southern hip hop', u'trap music'],
#  [u'bhangra', u'desi', u'indian pop', u'pakistani pop', u'punjabi'],
#  [u'alternative hip hop', u'underground hip hop'],
#  [u'crunk',
#   u'dirty south rap',
#   u'gangster rap',
#   u'hip pop',
#   u'memphis hip hop',
#   u'pop rap',
#   u'rap',
#   u'southern hip hop',
#   u'trap music'],
#  [u'french hip hop'],
#  [u'horrorcore'],
#  [u'crunk',
#   u'dirty south rap',
#   u'gangster rap',
#   u'pop rap',
#   u'rap',
#   u'southern hip hop',
#   u'trap music'],
#  [u'album rock',
#   u'art rock',
#   u'blues-rock',
#   u'brill building pop',
#   u'classic rock',
#   u'country rock',
#   u'folk-pop',
#   u'hard rock',
#   u'mellow gold',
#   u'permanent wave',
#   u'pop christmas',
#   u'pop rock',
#   u'rock',
#   u'rockabilly',
#   u'roots rock',
#   u'singer-songwriter',
#   u'soft rock',
#   u'traditional folk'],
#  [u'crunk',
#   u'dance pop',
#   u'dirty south rap',
#   u'hip hop',
#   u'hip pop',
#   u'pop rap',
#   u'r&b',
#   u'rap',
#   u'southern hip hop',
#   u'trap music',
#   u'urban contemporary'],
#  [u'dreamo', u'piano rock'],
#  [u'underground hip hop'],
#  [u'hip pop'],
#  [u'crunk',
#   u'dirty south rap',
#   u'pop rap',
#   u'rap',
#   u'southern hip hop',
#   u'trap music'],
#  [u'chicano rap',
#   u'dirty south rap',
#   u'gangster rap',
#   u'hip hop',
#   u'horrorcore',
#   u'hyphy',
#   u'west coast rap'],
#  [u'alternative hip hop', u'hardcore hip hop', u'hip hop'],
#  [u'rap', u'trap music'],
#  [u'crunk',
#   u'dirty south rap',
#   u'gangster rap',
#   u'hip hop',
#   u'hip pop',
#   u'pop rap',
#   u'rap',
#   u'southern hip hop',
#   u'trap music'],
#  [u'alternative hip hop', u'hardcore hip hop'],
#  [],
#  [u'deep east coast hip hop', u'hardcore hip hop', u'turntablism'],
#  [u'crunk',
#   u'dirty south rap',
#   u'gangster rap',
#   u'pop rap',
#   u'rap',
#   u'southern hip hop',
#   u'trap music'],
#  [u'abstract hip hop', u'alternative hip hop'],
#  [u'dirty south rap',
#   u'dirty texas rap',
#   u'g funk',
#   u'gangster rap',
#   u'hyphy',
#   u'memphis hip hop'],
#  [u'crunk',
#   u'dirty south rap',
#   u'east coast hip hop',
#   u'hardcore hip hop',
#   u'hip hop',
#   u'hip pop',
#   u'pop christmas',
#   u'pop rap',
#   u'rap'],
#  [u'g funk', u'west coast rap'],
#  [u'g funk', u'gangster rap', u'hyphy', u'west coast rap'],
#  [u'crunk',
#   u'dirty south rap',
#   u'gangster rap',
#   u'hyphy',
#   u'southern hip hop',
#   u'trap music',
#   u'wrestling'],
#  [u'deep trap', u'dirty south rap', u'dirty texas rap', u'trap music'],
#  [u'abstract hip hop',
#   u'alternative hip hop',
#   u'turntablism',
#   u'underground rap'],
#  [u'alternative rock',
#   u'blues-rock',
#   u'garage rock',
#   u'indie pop',
#   u'indie rock',
#   u'indietronica',
#   u'punk blues'],
#  [u'crunk',
#   u'dirty south rap',
#   u'east coast hip hop',
#   u'gangster rap',
#   u'hardcore hip hop',
#   u'hip hop',
#   u'hip pop',
#   u'pop rap',
#   u'rap',
#   u'southern hip hop',
#   u'trap music'],
#  [u'alternative hip hop',
#   u'east coast hip hop',
#   u'gangster rap',
#   u'hardcore hip hop',
#   u'hip hop'],
#  [],
#  [u'chicano rap',
#   u'g funk',
#   u'latin christmas',
#   u'latin hip hop',
#   u'west coast rap'],
#  [u'east coast hip hop', u'hardcore hip hop', u'hip hop'],
#  [u'hip hop',
#   u'indie r&b',
#   u'pop rap',
#   u'rap',
#   u'southern hip hop',
#   u'trap music',
#   u'underground hip hop'],
#  [u'crunk',
#   u'deep trap',
#   u'dirty south rap',
#   u'gangster rap',
#   u'pop rap',
#   u'rap',
#   u'southern hip hop',
#   u'trap music'],
#  [u'dirty south rap', u'gangster rap', u'hip hop', u'pop rap'],
#  [u'deep underground hip hop', u'trap music'],
#  [u'pop', u'tropical house'],
#  [u'dance pop',
#   u'dirty south rap',
#   u'hip hop',
#   u'hip pop',
#   u'indie r&b',
#   u'neo soul',
#   u'pop',
#   u'pop christmas',
#   u'pop rap',
#   u'r&b',
#   u'soul',
#   u'soul christmas',
#   u'southern hip hop',
#   u'urban contemporary'],
#  [u'hyphy'],
#  [u'g funk', u'hyphy', u'west coast rap'],
#  [],
#  [],
#  [u'turkish hip hop', u'turkish pop', u'turkish rock'],
#  [u'crunk',
#   u'dirty south rap',
#   u'gangster rap',
#   u'hip hop',
#   u'hip pop',
#   u'pop rap',
#   u'rap',
#   u'southern hip hop',
#   u'trap music'],
#  [u'pop rap', u'rap', u'trap music'],
#  [u'pop rap', u'rap', u'southern hip hop', u'trap music'],
#  [],
#  [u'alternative hip hop'],
#  [u'hip hop', u'pop rap', u'rap', u'trap music'],
#  [u'hip pop'],
#  [u'deep trap', u'rap', u'southern hip hop', u'trap music'],
#  [u'deep east coast hip hop', u'hardcore hip hop', u'old school hip hop'],
#  [u'hip hop', u'pop rap', u'rap', u'underground pop rap'],
#  [u'deep trap',
#   u'drill',
#   u'gangster rap',
#   u'hip hop',
#   u'pop rap',
#   u'rap',
#   u'southern hip hop',
#   u'trap music'],
#  [u'hip hop',
#   u'indie r&b',
#   u'pop rap',
#   u'rap',
#   u'southern hip hop',
#   u'trap music'],
#  [],
#  [u'crunk',
#   u'dance pop',
#   u'dirty south rap',
#   u'gangster rap',
#   u'hip hop',
#   u'hip pop',
#   u'pop rap',
#   u'r&b',
#   u'rap',
#   u'southern hip hop',
#   u'trap music',
#   u'urban contemporary'],
#  [u'hardcore hip hop', u'underground rap'],
#  [u'deep trap', u'rap', u'southern hip hop', u'trap music'],
#  [u'underground hip hop'],
#  [],
#  [u'bounce',
#   u'crunk',
#   u'dirty south rap',
#   u'pop rap',
#   u'southern hip hop',
#   u'trap music'],
#  [u'dance pop',
#   u'pop',
#   u'pop christmas',
#   u'pop rap',
#   u'r&b',
#   u'rap',
#   u'soul christmas',
#   u'urban contemporary'],
#  [u'underground pop rap'],
#  [u'dancehall', u'lovers rock'],
#  [u'east coast hip hop',
#   u'electro',
#   u'gangster rap',
#   u'hardcore hip hop',
#   u'hip hop',
#   u'hip pop',
#   u'miami bass',
#   u'old school hip hop'],
#  [],
#  [u'k-pop'],
#  [u'alternative hip hop',
#   u'east coast hip hop',
#   u'gangster rap',
#   u'hardcore hip hop',
#   u'hip hop',
#   u'rap',
#   u'turntablism'],
#  [u'underground pop rap'],
#  [u'pop rap', u'underground pop rap'],
#  [u'hyphy',
#   u'pop rap',
#   u'rap',
#   u'southern hip hop',
#   u'trap music',
#   u'west coast rap'],
#  [u'g funk', u'horrorcore', u'west coast rap'],
#  [u'alternative hip hop',
#   u'dirty south rap',
#   u'gangster rap',
#   u'hardcore hip hop',
#   u'hip hop',
#   u'neo soul',
#   u'pop rap',
#   u'rap',
#   u'southern hip hop'],
#  [u'alternative hip hop',
#   u'dirty south rap',
#   u'hardcore hip hop',
#   u'hip hop',
#   u'pop christmas',
#   u'pop rap',
#   u'rap',
#   u'southern hip hop'],
#  [],
#  [u'electro', u'old school hip hop'],
#  [u'crunk',
#   u'dirty south rap',
#   u'g funk',
#   u'gangster rap',
#   u'hardcore hip hop',
#   u'hip hop',
#   u'hip pop',
#   u'pop rap',
#   u'rap',
#   u'southern hip hop',
#   u'west coast rap'],
#  [u'abstract hip hop', u'underground rap'],
#  [u'alternative hip hop',
#   u'east coast hip hop',
#   u'hardcore hip hop',
#   u'hip hop'],
#  [u'pop rap', u'rap', u'southern hip hop', u'trap music'],
#  [u'alternative hip hop', u'turntablism'],
#  [u'alternative hip hop',
#   u'dirty south rap',
#   u'gangster rap',
#   u'hardcore hip hop',
#   u'hip hop',
#   u'southern hip hop',
#   u'turntablism'],
#  [u'gangster rap',
#   u'hardcore hip hop',
#   u'hip hop',
#   u'hip pop',
#   u'rap',
#   u'turntablism'],
#  [u'dirty south rap', u'dirty texas rap', u'memphis hip hop'],
#  [u'memphis hip hop'],
#  [u'gangster rap'],
#  [u'k-hop', u'korean pop'],
#  [u'crunk',
#   u'dirty south rap',
#   u'gangster rap',
#   u'hip hop',
#   u'pop rap',
#   u'rap',
#   u'southern hip hop',
#   u'underground hip hop'],
#  [],
#  [u'rap', u'trap music'],
#  [u'classic funk rock',
#   u'dance pop',
#   u'funk',
#   u'funk rock',
#   u'hip pop',
#   u'indie r&b',
#   u'neo soul',
#   u'new jack swing',
#   u'quiet storm',
#   u'r&b',
#   u'soul',
#   u'urban contemporary'],
#  [u'afrobeats'],
#  [u'east coast hip hop',
#   u'electro',
#   u'hardcore hip hop',
#   u'hip hop',
#   u'old school hip hop'],
#  [],
#  [u'chicano rap',
#   u'electro',
#   u'g funk',
#   u'gangster rap',
#   u'hardcore hip hop',
#   u'hip hop',
#   u'hyphy',
#   u'old school hip hop',
#   u'rap'],
#  [u'hip pop', u'new jack swing'],
#  [u'underground hip hop'],
#  [],
#  [],
#  [u'alternative hip hop', u'ambeat', u'turntablism', u'underground hip hop'],
#  [u'antiviral pop'],
#  [u'electro', u'hip hop', u'miami bass', u'old school hip hop'],
#  [u'new jack swing'],
#  [u'alternative hip hop',
#   u'detroit hip hop',
#   u'indie r&b',
#   u'pop rap',
#   u'rap',
#   u'southern hip hop',
#   u'underground hip hop'],
#  [u'grime'],
#  [u'underground hip hop'],
#  [],
#  [u'crunk',
#   u'dirty south rap',
#   u'gangster rap',
#   u'hip hop',
#   u'hip pop',
#   u'pop christmas',
#   u'pop rap',
#   u'rap',
#   u'southern hip hop',
#   u'trap music'],
#  [u'polynesian pop', u'underground pop rap', u'wrestling'],
#  [u'pop rap'],
#  [],
#  [u'g funk', u'west coast rap'],
#  [u'deep g funk'],
#  [],
#  [u'hardcore hip hop', u'hip hop'],
#  [u'detroit hip hop', u'rap', u'trap music'],
#  [u'alternative hip hop',
#   u'dirty south rap',
#   u'gangster rap',
#   u'hardcore hip hop',
#   u'hip hop',
#   u'southern hip hop',
#   u'turntablism'],
#  [u'deep underground hip hop'],
#  [u'underground hip hop'],
#  [u'drill', u'hip hop', u'rap', u'underground hip hop'],
#  [u'christian hip hop'],
#  [u'dwn trap', u'rap', u'trap music'],
#  [],
#  [u'alternative metal', u'post-grunge', u'rap metal', u'rap rock'],
#  [u'dance pop', u'pop', u'pop rap'],
#  [u'crunk',
#   u'dirty south rap',
#   u'gangster rap',
#   u'hardcore hip hop',
#   u'hip hop',
#   u'pop rap',
#   u'southern hip hop'],
#  [u'channel pop', u'talent show'],
#  [],
#  [u'adult standards',
#   u'album rock',
#   u'art rock',
#   u'brill building pop',
#   u'bubblegum pop',
#   u'christmas',
#   u'classic rock',
#   u'folk',
#   u'folk christmas',
#   u'folk rock',
#   u'mellow gold',
#   u'motown',
#   u'rock',
#   u'rock-and-roll',
#   u'rockabilly',
#   u'roots rock',
#   u'singer-songwriter',
#   u'soft rock',
#   u'soul',
#   u'traditional folk'],
#  [u'alternative hip hop',
#   u'east coast hip hop',
#   u'hardcore hip hop',
#   u'hip hop',
#   u'turntablism'],
#  [],
#  [],
#  [u'ghettotech'],
#  [u'bassline', u'electronic', u'grime', u'pop rap', u'uk garage'],
#  [u'rap', u'trap music', u'underground hip hop'],
#  [],
#  [],
#  [u'detroit hip hop', u'horrorcore'],
#  [u'east coast hip hop', u'hardcore hip hop', u'hip pop'],
#  [u'crunk',
#   u'dirty south rap',
#   u'gangster rap',
#   u'hip hop',
#   u'pop rap',
#   u'rap',
#   u'southern hip hop',
#   u'trap music'],
#  [u'crunk', u'dirty south rap', u'pop rap', u'southern hip hop'],
#  [u'francoton'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [u'crunk',
#   u'dirty south rap',
#   u'gangster rap',
#   u'hip hop',
#   u'pop rap',
#   u'rap',
#   u'southern hip hop',
#   u'trap music'],
#  [u'acid jazz',
#   u'big beat',
#   u'breakbeat',
#   u'downtempo',
#   u'electronic',
#   u'j-rap',
#   u'ninja',
#   u'nu jazz',
#   u'trip hop',
#   u'turntablism'],
#  [u'rap', u'southern hip hop', u'trap music'],
#  [u'bounce',
#   u'crunk',
#   u'dirty south rap',
#   u'gangster rap',
#   u'happy hardcore',
#   u'memphis hip hop',
#   u'southern hip hop',
#   u'trap music'],
#  [u'deep g funk', u'west coast rap'],
#  [u'alternative hip hop',
#   u'east coast hip hop',
#   u'hardcore hip hop',
#   u'hip hop',
#   u'turntablism'],
#  [u'dirty south rap',
#   u'g funk',
#   u'gangster rap',
#   u'hardcore hip hop',
#   u'hip hop',
#   u'hyphy',
#   u'pop rap',
#   u'rap',
#   u'southern hip hop',
#   u'west coast rap'],
#  [u'crunk',
#   u'dirty south rap',
#   u'gangster rap',
#   u'memphis hip hop',
#   u'trap music'],
#  [u'big beat',
#   u'downtempo',
#   u'electronic',
#   u'ninja',
#   u'nu jazz',
#   u'trip hop',
#   u'turntablism'],
#  [u'g funk'],
#  [u'crunk',
#   u'dirty south rap',
#   u'east coast hip hop',
#   u'gangster rap',
#   u'hardcore hip hop',
#   u'hip hop',
#   u'hip pop',
#   u'pop rap',
#   u'rap',
#   u'southern hip hop'],
#  [],
#  [u'deep trap', u'rap', u'southern hip hop', u'trap music'],
#  [u'k-hop', u'k-pop', u'korean pop'],
#  [u'pop rap', u'rap', u'trap music'],
#  [u'hip hop',
#   u'pop rap',
#   u'rap',
#   u'southern hip hop',
#   u'trap music',
#   u'underground hip hop'],
#  [u'escape room', u'hip pop'],
#  [u'adult standards',
#   u'brill building pop',
#   u'chicago soul',
#   u'christmas',
#   u'doo-wop',
#   u'jazz blues',
#   u'jazz christmas',
#   u'lounge',
#   u'memphis soul',
#   u'motown',
#   u'new orleans blues',
#   u'piano blues',
#   u'rock-and-roll',
#   u'rockabilly',
#   u'soul',
#   u'soul blues',
#   u'soul christmas',
#   u'southern soul'],
#  [u'escape room', u'rap', u'underground hip hop'],
#  [],
#  [u'pop rap',
#   u'rap',
#   u'southern hip hop',
#   u'trap music',
#   u'underground pop rap'],
#  [u'crunk', u'pop christmas', u'pop rap', u'southern hip hop'],
#  [u'abstract hip hop'],
#  [u'east coast hip hop',
#   u'electro',
#   u'hardcore hip hop',
#   u'hip hop',
#   u'old school hip hop',
#   u'rap'],
#  [u'deep southern trap', u'dirty south rap'],
#  [u'crunk',
#   u'dirty south rap',
#   u'g funk',
#   u'gangster rap',
#   u'hip hop',
#   u'hip pop',
#   u'pop rap',
#   u'rap',
#   u'southern hip hop',
#   u'trap music',
#   u'west coast rap'],
#  [u'crunk',
#   u'dirty south rap',
#   u'gangster rap',
#   u'hardcore hip hop',
#   u'hip hop',
#   u'hip pop',
#   u'pop rap',
#   u'rap',
#   u'southern hip hop'],
#  [u'canadian pop', u'hip hop', u'pop rap', u'rap'],
#  [u'deep east coast hip hop', u'flick hop'],
#  [],
#  [u'polynesian pop'],
#  [u'pop rap', u'rap', u'southern hip hop', u'trap music'],
#  [],
#  [u'g funk', u'hyphy', u'west coast rap'],
#  [u'crunk',
#   u'deep trap',
#   u'dirty south rap',
#   u'gangster rap',
#   u'memphis hip hop',
#   u'pop rap',
#   u'rap',
#   u'southern hip hop',
#   u'trap music'],
#  [u'k-hop', u'underground hip hop', u'underground pop rap'],
#  [u'afrobeats', u'azonto', u'azontobeats', u'kwaito house'],
#  [u'crunk',
#   u'dirty south rap',
#   u'gangster rap',
#   u'hip hop',
#   u'hyphy',
#   u'pop rap',
#   u'rap',
#   u'southern hip hop',
#   u'trap music',
#   u'west coast rap'],
#  [],
#  [u'dirty south rap', u'dirty texas rap', u'gangster rap', u'memphis hip hop'],
#  [u'alternative hip hop',
#   u'hip hop',
#   u'indie r&b',
#   u'pop rap',
#   u'rap',
#   u'southern hip hop',
#   u'underground hip hop'],
#  [],
#  [u'crunk',
#   u'dirty south rap',
#   u'g funk',
#   u'gangster rap',
#   u'hardcore hip hop',
#   u'hip hop',
#   u'pop rap',
#   u'rap',
#   u'west coast rap'],
#  [],
#  [u'croatian pop', u'turbo folk', u'yugoslav rock'],
#  [u'hardcore hip hop', u'underground rap'],
#  [u'abstract hip hop',
#   u'alternative hip hop',
#   u'east coast hip hop',
#   u'hardcore hip hop',
#   u'hip hop',
#   u'turntablism'],
#  [u'dancehall', u'reggae fusion'],
#  [u'alternative hip hop', u'detroit hip hop'],
#  [u'detroit hip hop', u'g funk', u'hip hop', u'pop rap', u'rap'],
#  [],
#  [u'alternative hip hop',
#   u'gangster rap',
#   u'hardcore hip hop',
#   u'hip hop',
#   u'hip pop',
#   u'rap',
#   u'turntablism'],
#  [u'classify'],
#  [u'detroit hip hop', u'horrorcore', u'memphis hip hop'],
#  [u'crunk',
#   u'dance pop',
#   u'dirty south rap',
#   u'hip hop',
#   u'hip pop',
#   u'pop rap',
#   u'r&b',
#   u'rap',
#   u'southern hip hop',
#   u'urban contemporary'],
#  [],
#  [u'abstract hip hop', u'alternative hip hop', u'underground rap'],
#  [u'crunk',
#   u'dirty south rap',
#   u'gangster rap',
#   u'hardcore hip hop',
#   u'hip hop',
#   u'hip pop',
#   u'pop rap',
#   u'rap',
#   u'trap music'],
#  [u'italian hip hop', u'italian pop'],
#  [u'dirty south rap', u'southern hip hop'],
#  [u'alternative hip hop', u'hip hop', u'pop rap', u'underground hip hop'],
#  [u'dirty south rap',
#   u'east coast hip hop',
#   u'gangster rap',
#   u'hardcore hip hop',
#   u'hip hop',
#   u'hip pop',
#   u'pop rap',
#   u'rap',
#   u'trap music'],
#  [u'crunk',
#   u'dirty south rap',
#   u'gangster rap',
#   u'memphis hip hop',
#   u'southern hip hop'],
#  [u'deep trap', u'trap music'],
#  [],
#  [u'new jack swing'],
#  [u'hip pop', u'pop rap'],
#  [u'dance pop',
#   u'hip pop',
#   u'pop',
#   u'pop rap',
#   u'post-teen pop',
#   u'r&b',
#   u'urban contemporary'],
#  [u'pop rap', u'rap', u'trap music'],
#  [u'crunk', u'dirty south rap', u'gangster rap', u'memphis hip hop'],
#  [u'crunk',
#   u'dirty south rap',
#   u'gangster rap',
#   u'hip hop',
#   u'pop rap',
#   u'rap',
#   u'southern hip hop',
#   u'trap music'],
#  [u'east coast hip hop',
#   u'gangster rap',
#   u'hardcore hip hop',
#   u'hip hop',
#   u'rap'],
#  [u'afrobeats', u'azonto', u'azontobeats'],
#  [u'dance pop',
#   u'hip pop',
#   u'pop',
#   u'pop rap',
#   u'r&b',
#   u'rap',
#   u'southern hip hop'],
#  [u'alternative hip hop',
#   u'escape room',
#   u'glitch',
#   u'glitch hop',
#   u'indie r&b',
#   u'indietronica',
#   u'trip hop',
#   u'turntablism',
#   u'wonky'],
#  [],
#  [],
#  [u'hip hop',
#   u'nu metal',
#   u'pop rap',
#   u'post-grunge',
#   u'rap',
#   u'rap metal',
#   u'rap rock'],
#  [u'dance pop',
#   u'hip pop',
#   u'neo soul',
#   u'new jack swing',
#   u'pop rap',
#   u'r&b',
#   u'urban contemporary'],
#  [u'dirty south rap',
#   u'east coast hip hop',
#   u'gangster rap',
#   u'hardcore hip hop',
#   u'hip hop',
#   u'hip pop',
#   u'pop rap',
#   u'r&b',
#   u'rap',
#   u'southern hip hop'],
#  [u'dance pop', u'indie r&b', u'neo soul', u'pop', u'pop rap', u'r&b', u'rap'],
#  [u'alternative r&b',
#   u'dance pop',
#   u'hip pop',
#   u'pop',
#   u'pop rap',
#   u'r&b',
#   u'urban contemporary'],
#  [u'crunk',
#   u'dirty south rap',
#   u'gangster rap',
#   u'memphis hip hop',
#   u'southern hip hop',
#   u'trap music'],
#  [u'crunk',
#   u'dirty south rap',
#   u'miami bass',
#   u'pop rap',
#   u'southern hip hop'],
#  [u'deep east coast hip hop', u'hardcore hip hop', u'turntablism'],
#  [u'alternative hip hop',
#   u'dirty south rap',
#   u'pop rap',
#   u'rap',
#   u'southern hip hop',
#   u'trap music',
#   u'underground hip hop'],
#  [u'deep trap',
#   u'drill',
#   u'rap',
#   u'southern hip hop',
#   u'trap music',
#   u'underground hip hop'],
#  [u'gangster rap', u'hardcore hip hop', u'hip hop', u'hip pop'],
#  [],
#  [u'ccm', u'christian music', u'christian rock', u'worship'],
#  [],
#  [u'crunk',
#   u'dirty south rap',
#   u'gangster rap',
#   u'hardcore hip hop',
#   u'hip hop',
#   u'hip pop',
#   u'pop rap',
#   u'rap',
#   u'southern hip hop'],
#  [u'hip hop', u'pop rap', u'rap', u'southern hip hop', u'trap music'],
#  [u'turbo folk', u'yugoslav rock'],
#  [],
#  [],
#  [u'austindie', u'indietronica'],
#  [],
#  [u'east coast hip hop',
#   u'gangster rap',
#   u'hardcore hip hop',
#   u'hip hop',
#   u'hip pop',
#   u'rap',
#   u'turntablism'],
#  [u'deep trap', u'pop rap', u'rap', u'southern hip hop', u'trap music'],
#  [u'dance pop', u'k-hop', u'k-pop'],
#  [u'pop rap', u'rap', u'underground pop rap'],
#  [u'hardcore hip hop', u'hip pop'],
#  [u'korean pop'],
#  [u'crunk',
#   u'dirty south rap',
#   u'gangster rap',
#   u'hip hop',
#   u'pop rap',
#   u'rap',
#   u'southern hip hop',
#   u'trap music'],
#  [u'dirty south rap', u'dirty texas rap', u'gangster rap', u'memphis hip hop'],
#  [u'crunk',
#   u'dirty south rap',
#   u'gangster rap',
#   u'memphis hip hop',
#   u'southern hip hop',
#   u'trap music'],
#  [u'contemporary country',
#   u'country',
#   u'country christmas',
#   u'country road',
#   u'modern country rock'],
#  [u'yugoslav rock'],
#  [u'alternative hip hop',
#   u'dirty south rap',
#   u'east coast hip hop',
#   u'gangster rap',
#   u'hardcore hip hop',
#   u'hip hop',
#   u'pop rap',
#   u'rap',
#   u'southern hip hop'],
#  [u'grime', u'uk hip hop'],
#  [u'underground pop rap'],
#  [u'dirty south rap',
#   u'gangster rap',
#   u'hyphy',
#   u'pop rap',
#   u'rap',
#   u'southern hip hop',
#   u'trap music',
#   u'west coast trap'],
#  [u'dirty south rap', u'pop rap', u'rap', u'southern hip hop'],
#  [u'g funk', u'gangster rap', u'hyphy', u'west coast rap'],
#  [u'crunk',
#   u'dirty south rap',
#   u'gangster rap',
#   u'hip pop',
#   u'pop rap',
#   u'rap',
#   u'southern hip hop',
#   u'trap music'],
#  [],
#  [u'alternative hip hop',
#   u'east coast hip hop',
#   u'gangster rap',
#   u'hardcore hip hop',
#   u'hip hop',
#   u'turntablism'],
#  [u'old school hip hop'],
#  [u'east coast hip hop',
#   u'electro',
#   u'gangster rap',
#   u'hardcore hip hop',
#   u'hip hop',
#   u'old school hip hop',
#   u'rap',
#   u'turntablism'],
#  [u'abstract hip hop', u'underground rap'],
#  [u'underground pop rap'],
#  [u'crunk',
#   u'deep trap',
#   u'dirty south rap',
#   u'doujin',
#   u'gangster rap',
#   u'pop rap',
#   u'rap',
#   u'southern hip hop',
#   u'trap music'],
#  [u'crunk',
#   u'deep trap',
#   u'dirty south rap',
#   u'pop rap',
#   u'rap',
#   u'southern hip hop',
#   u'trap music'],
#  [u'crunk',
#   u'dirty south rap',
#   u'gangster rap',
#   u'hardcore hip hop',
#   u'hip hop',
#   u'hip pop',
#   u'hyphy',
#   u'pop rap',
#   u'rap',
#   u'southern hip hop',
#   u'west coast rap'],
#  [u'alternative hip hop', u'detroit hip hop'],
#  [u'deep trap', u'gangster rap', u'rap', u'southern hip hop', u'trap music'],
#  [u'alternative hip hop',
#   u'east coast hip hop',
#   u'gangster rap',
#   u'hardcore hip hop',
#   u'hip hop',
#   u'rap',
#   u'turntablism'],
#  [u'alternative hip hop',
#   u'east coast hip hop',
#   u'gangster rap',
#   u'hardcore hip hop',
#   u'hip hop',
#   u'rap',
#   u'southern hip hop',
#   u'turntablism'],
#  [],
#  [u'bhangra', u'desi', u'filmi', u'indian pop', u'punjabi'],
#  [u'flick hop', u'underground rap'],
#  [u'hardcore hip hop'],
#  [u'east coast hip hop', u'hip hop', u'new jack swing', u'old school hip hop'],
#  [],
#  [u'g funk', u'gangster rap', u'hyphy', u'west coast rap'],
#  [u'alternative hip hop', u'hardcore hip hop', u'hip hop', u'turntablism'],
#  [],
#  [u'gangster rap'],
#  [u'escape room', u'rap', u'underground hip hop'],
#  [u'deep pop r&b', u'rap', u'trap music'],
#  [u'pop rap', u'rap', u'underground pop rap'],
#  [u'hip hop', u'pop rap', u'rap'],
#  [u'crunk', u'dirty south rap', u'southern hip hop', u'trap music'],
#  [u'album rock',
#   u'classic rock',
#   u'dance rock',
#   u'hard rock',
#   u'mellow gold',
#   u'new romantic',
#   u'new wave',
#   u'new wave pop',
#   u'rock',
#   u'soft rock'],
#  [u'crunk',
#   u'dirty south rap',
#   u'gangster rap',
#   u'hip pop',
#   u'pop rap',
#   u'rap',
#   u'southern hip hop',
#   u'trap music'],
#  [u'deep east coast hip hop', u'hardcore hip hop'],
#  [u'chicago indie',
#   u'dreamo',
#   u'emo',
#   u'piano rock',
#   u'pop punk',
#   u'pop rock'],
#  [],
#  [u'crunk',
#   u'dirty south rap',
#   u'gangster rap',
#   u'hip pop',
#   u'pop rap',
#   u'rap',
#   u'southern hip hop',
#   u'trap music'],
#  [u'rap', u'southern hip hop', u'trap music'],
#  [u'crunk',
#   u'dirty south rap',
#   u'g funk',
#   u'gangster rap',
#   u'hardcore hip hop',
#   u'hip hop',
#   u'pop rap',
#   u'rap',
#   u'southern hip hop',
#   u'west coast rap'],
#  [u'chicano rap',
#   u'dirty south rap',
#   u'gangster rap',
#   u'hardcore hip hop',
#   u'hip hop',
#   u'old school hip hop',
#   u'rap',
#   u'west coast rap'],
#  [u'dance pop', u'hip pop', u'pop', u'pop rap', u'post-teen pop'],
#  [u'dwn trap', u'trap music'],
#  [u'hardcore hip hop'],
#  [],
#  [u'indie r&b', u'pop rap', u'rap', u'southern hip hop', u'trap music'],
#  [u'alternative hip hop',
#   u'east coast hip hop',
#   u'gangster rap',
#   u'hardcore hip hop',
#   u'hip hop',
#   u'pop rap',
#   u'rap'],
#  [u'bhangra', u'desi', u'indian pop', u'punjabi'],
#  [u'crunk',
#   u'dirty south rap',
#   u'gangster rap',
#   u'memphis hip hop',
#   u'southern hip hop'],
#  [u'east coast hip hop', u'hardcore hip hop', u'hip hop'],
#  [u'rap', u'underground hip hop'],
#  [u'afrobeats', u'azonto', u'azontobeats'],
#  [u'dance pop',
#   u'pop',
#   u'pop rap',
#   u'post-teen pop',
#   u'r&b',
#   u'urban contemporary'],
#  [u'alternative hip hop', u'detroit hip hop', u'hip hop', u'turntablism'],
#  [u'hyphy'],
#  [u'crunk',
#   u'dirty south rap',
#   u'gangster rap',
#   u'hip hop',
#   u'hip pop',
#   u'pop rap',
#   u'rap',
#   u'southern hip hop',
#   u'trap music'],
#  [u'swedish eurodance', u'swedish hip hop'],
#  [u'pop rap', u'rap', u'southern hip hop'],
#  [u'hyphy', u'west coast rap'],
#  [u'alternative r&b', u'deep pop r&b', u'r&b'],
#  [],
#  [],
#  [u'crunk',
#   u'dirty south rap',
#   u'pop rap',
#   u'southern hip hop',
#   u'trap music'],
#  [u'crunk',
#   u'dance pop',
#   u'dirty south rap',
#   u'east coast hip hop',
#   u'gangster rap',
#   u'hardcore hip hop',
#   u'hip hop',
#   u'hip pop',
#   u'pop rap',
#   u'r&b',
#   u'rap',
#   u'urban contemporary'],
#  [u'afrikaans', u'dutch hip hop'],
#  [u'hyphy'],
#  [u'christian hip hop'],
#  [u'crunk',
#   u'dirty south rap',
#   u'east coast hip hop',
#   u'gangster rap',
#   u'hardcore hip hop',
#   u'hip hop',
#   u'hip pop',
#   u'pop rap',
#   u'rap',
#   u'trap music'],
#  [u'crunk',
#   u'dirty south rap',
#   u'pop rap',
#   u'rap',
#   u'southern hip hop',
#   u'trap music'],
#  [u'deep trap', u'trap music'],
#  [u'pop', u'post-teen pop', u'underground pop rap'],
#  [u'alternative hip hop', u'underground rap'],
#  [],
#  [u'bebop',
#   u'contemporary post-bop',
#   u'cool jazz',
#   u'hard bop',
#   u'jazz',
#   u'jazz blues',
#   u'jazz funk',
#   u'jazz fusion',
#   u'soul jazz',
#   u'stride'],
#  [u'dance pop',
#   u'hip pop',
#   u'neo soul',
#   u'new jack swing',
#   u'pop rap',
#   u'r&b',
#   u'urban contemporary'],
#  [u'underground hip hop'],
#  [u'slow game'],
#  [u'alternative hip hop',
#   u'dirty south rap',
#   u'hardcore hip hop',
#   u'hip hop',
#   u'pop rap',
#   u'rap',
#   u'southern hip hop',
#   u'underground hip hop'],
#  [u'dance pop', u'k-pop'],
#  [u'gangster rap',
#   u'hip hop',
#   u'pop rap',
#   u'rap',
#   u'southern hip hop',
#   u'trap music',
#   u'underground hip hop'],
#  [u'dirty south rap',
#   u'east coast hip hop',
#   u'gangster rap',
#   u'hip hop',
#   u'pop',
#   u'pop rap',
#   u'rap',
#   u'southern hip hop',
#   u'trap music'],
#  [u'g funk', u'gangster rap', u'hyphy', u'west coast rap'],
#  [],
#  [u'crunk', u'dirty south rap', u'hip pop', u'pop rap', u'southern hip hop'],
#  [u'alternative hip hop',
#   u'east coast hip hop',
#   u'hardcore hip hop',
#   u'hip hop',
#   u'hip pop'],
#  [u'abstract beats', u'alternative hip hop', u'wonky'],
#  [u'dance pop',
#   u'pop',
#   u'pop christmas',
#   u'pop rap',
#   u'r&b',
#   u'rap',
#   u'southern hip hop',
#   u'trap music'],
#  [u'crunk',
#   u'dirty south rap',
#   u'gangster rap',
#   u'hardcore hip hop',
#   u'hip hop',
#   u'hip pop',
#   u'pop rap',
#   u'rap',
#   u'southern hip hop',
#   u'trap music'],
#  [u'alternative hip hop',
#   u'east coast hip hop',
#   u'gangster rap',
#   u'hardcore hip hop',
#   u'hip hop',
#   u'rap',
#   u'turntablism'],
#  [u'contemporary country',
#   u'country',
#   u'country road',
#   u'modern country rock'],
#  [u'crunk',
#   u'dirty south rap',
#   u'gangster rap',
#   u'hip hop',
#   u'hip pop',
#   u'pop rap',
#   u'rap',
#   u'southern hip hop',
#   u'trap music'],
#  [u'crunk',
#   u'dirty south rap',
#   u'gangster rap',
#   u'hip hop',
#   u'hip pop',
#   u'pop rap',
#   u'rap',
#   u'trap music'],
#  [],
#  [u'grime'],
#  [u'crunk',
#   u'dirty south rap',
#   u'gangster rap',
#   u'hardcore hip hop',
#   u'hip hop',
#   u'hip pop',
#   u'pop rap',
#   u'rap',
#   u'trap music'],
#  [u'alternative hip hop',
#   u'gangster rap',
#   u'hardcore hip hop',
#   u'hip hop',
#   u'pop rap',
#   u'rap',
#   u'southern hip hop'],
#  [u'hip hop', u'pop rap', u'rap', u'underground hip hop'],
#  [u'wrestling'],
#  [],
#  [u'alternative r&b'],
#  [u'underground hip hop'],
#  [u'crunk',
#   u'dirty south rap',
#   u'gangster rap',
#   u'hip pop',
#   u'memphis hip hop',
#   u'miami bass',
#   u'pop rap',
#   u'southern hip hop'],
#  [u'west coast rap'],
#  [u'crunk',
#   u'dirty south rap',
#   u'gangster rap',
#   u'hardcore hip hop',
#   u'hip hop',
#   u'hip pop',
#   u'pop christmas',
#   u'pop rap',
#   u'rap',
#   u'trap music'],
#  [u'crunk',
#   u'dirty south rap',
#   u'gangster rap',
#   u'hip hop',
#   u'memphis hip hop',
#   u'pop rap',
#   u'rap',
#   u'southern hip hop',
#   u'trap music'],
#  [],
#  [u'underground rap'],
#  [u'east coast hip hop',
#   u'electro',
#   u'hardcore hip hop',
#   u'hip hop',
#   u'old school hip hop'],
#  [u'bounce',
#   u'crunk',
#   u'dirty south rap',
#   u'gangster rap',
#   u'hip hop',
#   u'hip pop',
#   u'pop rap',
#   u'rap',
#   u'southern hip hop',
#   u'trap music'],
#  [u'deep trap', u'pop rap', u'rap', u'southern hip hop', u'trap music'],
#  [u'pop rap'],
#  [u'west coast rap'],
#  [u'alternative hip hop',
#   u'dirty south rap',
#   u'hip hop',
#   u'pop rap',
#   u'turntablism'],
#  [u'hardcore hip hop'],
#  [],
#  [u'freestyle', u'hip house'],
#  [u'hyphy', u'west coast trap'],
#  [u'deep g funk', u'gangster rap', u'hyphy', u'west coast rap'],
#  [],
#  [u'pop christmas', u'pop rap', u'rap', u'trap music'],
#  [u'deep trap', u'trap music'],
#  [u'canadian hip hop',
#   u'crunk',
#   u'dance pop',
#   u'dirty south rap',
#   u'gangster rap',
#   u'hip hop',
#   u'hip pop',
#   u'pop rap',
#   u'rap',
#   u'southern hip hop'],
#  [u'latin hip hop'],
#  [u'hip pop', u'pop', u'post-teen pop'],
#  [u'deep trap', u'drill', u'trap music'],
#  [u'christian hip hop', u'demoscene'],
#  [u'hyphy', u'west coast rap'],
#  [u'alternative hip hop',
#   u'gangster rap',
#   u'hardcore hip hop',
#   u'hip hop',
#   u'hip pop',
#   u'turntablism'],
#  [u'hip hop', u'pop rap', u'rap', u'trap music', u'west coast rap'],
#  [u'australian hip hop'],
#  [u'deep trap', u'pop rap', u'rap', u'southern hip hop', u'trap music'],
#  [u'alternative r&b', u'r&b'],
#  [u'crunk',
#   u'dance pop',
#   u'dirty south rap',
#   u'hip pop',
#   u'pop rap',
#   u'r&b',
#   u'southern hip hop'],
#  [],
#  [u'crunk',
#   u'deep trap',
#   u'dirty south rap',
#   u'gangster rap',
#   u'memphis hip hop',
#   u'pop rap',
#   u'rap',
#   u'southern hip hop',
#   u'trap music'],
#  [u'hardcore hip hop', u'hip hop', u'turntablism'],
#  [u'dance pop',
#   u'dirty south rap',
#   u'hip hop',
#   u'pop rap',
#   u'rap',
#   u'southern hip hop',
#   u'trap music'],
#  [u'chicano rap'],
#  [u'hip hop', u'pop rap', u'rap', u'southern hip hop', u'trap music'],
#  [u'alternative metal',
#   u'contemporary country',
#   u'country',
#   u'funk rock',
#   u'hard rock',
#   u'nu metal',
#   u'post-grunge',
#   u'rap metal',
#   u'rap rock',
#   u'rock'],
#  [u'bmore', u'hip pop', u'moombahton'],
#  [u'deep trap',
#   u'gangster rap',
#   u'pop rap',
#   u'rap',
#   u'southern hip hop',
#   u'trap music'],
#  [u'east coast hip hop', u'hardcore hip hop'],
#  [u'alternative hip hop',
#   u'crunk',
#   u'dirty south rap',
#   u'gangster rap',
#   u'hardcore hip hop',
#   u'hip hop',
#   u'pop rap',
#   u'rap',
#   u'southern hip hop',
#   u'trap music'],
#  [u'crunk',
#   u'dirty south rap',
#   u'gangster rap',
#   u'hip pop',
#   u'memphis hip hop',
#   u'miami bass',
#   u'pop rap',
#   u'southern hip hop',
#   u'trap music'],
#  [u'underground hip hop'],
#  [u'detroit hip hop', u'horrorcore'],
#  [],
#  [u'old school hip hop', u'west coast rap'],
#  [u'crunk',
#   u'deep trap',
#   u'dirty south rap',
#   u'gangster rap',
#   u'hip hop',
#   u'pop rap',
#   u'rap',
#   u'southern hip hop',
#   u'trap music'],
#  [u'escape room', u'vapor twitch'],
#  [u'ccm',
#   u'christian alternative rock',
#   u'christian christmas',
#   u'christian hip hop',
#   u'christian music',
#   u'christian rock'],
#  [],
#  [u'chicano rap', u'g funk', u'gangster rap', u'hip hop', u'west coast rap'],
#  [],
#  [u'dwn trap', u'rap', u'trap music'],
#  [u'g funk', u'gangster rap', u'hyphy', u'west coast rap'],
#  [u'escape room', u'underground hip hop'],
#  [u'alternative hip hop',
#   u'east coast hip hop',
#   u'gangster rap',
#   u'hardcore hip hop',
#   u'hip hop',
#   u'old school hip hop',
#   u'turntablism'],
#  [u'alternative hip hop',
#   u'east coast hip hop',
#   u'gangster rap',
#   u'hardcore hip hop',
#   u'hip hop',
#   u'turntablism'],
#  [u'east coast hip hop',
#   u'electro',
#   u'gangster rap',
#   u'hardcore hip hop',
#   u'hip hop',
#   u'new jack swing',
#   u'old school hip hop',
#   u'rap'],
#  [],
#  [u'crunk',
#   u'dirty south rap',
#   u'gangster rap',
#   u'hardcore hip hop',
#   u'hip hop',
#   u'pop rap',
#   u'rap',
#   u'southern hip hop'],
#  [u'escape room',
#   u'hip hop',
#   u'pop rap',
#   u'rap',
#   u'southern hip hop',
#   u'trap music'],
#  [],
#  [u'alternative hip hop',
#   u'dirty south rap',
#   u'east coast hip hop',
#   u'gangster rap',
#   u'hardcore hip hop',
#   u'hip hop',
#   u'old school hip hop',
#   u'pop rap',
#   u'rap',
#   u'southern hip hop',
#   u'turntablism'],
#  [u'horrorcore'],
#  [u'deep east coast hip hop', u'hardcore hip hop', u'turntablism'],
#  [u'east coast hip hop',
#   u'electro',
#   u'gangster rap',
#   u'hardcore hip hop',
#   u'hip hop',
#   u'miami bass',
#   u'old school hip hop',
#   u'rap'],
#  [u'dirty south rap',
#   u'g funk',
#   u'gangster rap',
#   u'hardcore hip hop',
#   u'hip hop',
#   u'rap',
#   u'west coast rap'],
#  [],
#  [],
#  [],
#  [],
#  [u'crunk',
#   u'dirty south rap',
#   u'gangster rap',
#   u'memphis hip hop',
#   u'southern hip hop',
#   u'trap music'],
#  [u'hardcore hip hop'],
#  [],
#  [u'g funk', u'gangster rap', u'hip pop'],
#  [u'deep east coast hip hop'],
#  [],
#  [u'alternative hip hop',
#   u'east coast hip hop',
#   u'hardcore hip hop',
#   u'hip hop',
#   u'turntablism'],
#  [u'hyphy'],
#  [u'dance pop',
#   u'hip hop',
#   u'hip pop',
#   u'indie r&b',
#   u'neo soul',
#   u'new jack swing',
#   u'pop',
#   u'pop christmas',
#   u'pop rap',
#   u'quiet storm',
#   u'r&b',
#   u'soul',
#   u'southern hip hop',
#   u'urban contemporary'],
#  [u'microhouse', u'minimal techno', u'tech house'],
#  [],
#  [u'christian hip hop'],
#  [u'underground hip hop'],
#  [u'deep trap', u'rap', u'trap music', u'underground hip hop'],
#  [u'deep trap', u'drill', u'trap music'],
#  [u'underground hip hop'],
#  [u'escape room', u'rap', u'trap music', u'underground hip hop'],
#  [u'rap', u'trap music'],
#  [u'deep trap',
#   u'drill',
#   u'hip hop',
#   u'rap',
#   u'southern hip hop',
#   u'trap music'],
#  [u'g funk', u'gangster rap', u'west coast rap'],
#  [u'deep trap', u'drill', u'trap music', u'underground hip hop'],
#  [u'crunk',
#   u'dance pop',
#   u'dirty south rap',
#   u'gangster rap',
#   u'hip hop',
#   u'hip pop',
#   u'pop rap',
#   u'rap',
#   u'southern hip hop',
#   u'trap music'],
#  [u'crunk',
#   u'dance pop',
#   u'hip pop',
#   u'pop',
#   u'pop rap',
#   u'post-teen pop',
#   u'r&b',
#   u'southern hip hop',
#   u'urban contemporary'],
#  [u'deep trap', u'trap music'],
#  [u'deep trap', u'drill', u'rap', u'southern hip hop', u'trap music'],
#  [u'deep g funk', u'dirty texas rap', u'hyphy'],
#  [u'crunk', u'southern hip hop', u'trap music'],
#  [u'crunk',
#   u'dirty south rap',
#   u'gangster rap',
#   u'hip hop',
#   u'hip pop',
#   u'pop rap',
#   u'rap',
#   u'southern hip hop',
#   u'trap music',
#   u'wrestling'],
#  [u'crunk', u'pop rap', u'rap', u'southern hip hop', u'trap music'],
#  [u'dwn trap', u'rap', u'trap music'],
#  [u'crunk',
#   u'dirty south rap',
#   u'hip hop',
#   u'pop christmas',
#   u'pop rap',
#   u'rap',
#   u'southern hip hop',
#   u'trap music'],
#  [u'crunk',
#   u'dirty south rap',
#   u'gangster rap',
#   u'memphis hip hop',
#   u'pop rap',
#   u'rap',
#   u'southern hip hop',
#   u'trap music'],
#  [u'dwn trap', u'rap', u'trap music'],
#  [u'crunk', u'dirty south rap', u'hip pop', u'pop rap', u'southern hip hop'],
#  [u'hip pop'],
#  [u'alternative r&b'],
#  [u'crunk',
#   u'dirty south rap',
#   u'gangster rap',
#   u'hip pop',
#   u'pop rap',
#   u'rap',
#   u'southern hip hop',
#   u'trap music'],
#  [u'crunk',
#   u'dirty south rap',
#   u'gangster rap',
#   u'pop rap',
#   u'southern hip hop',
#   u'trap music'],
#  [u'crunk',
#   u'dance pop',
#   u'dirty south rap',
#   u'east coast hip hop',
#   u'gangster rap',
#   u'hardcore hip hop',
#   u'hip hop',
#   u'hip pop',
#   u'pop rap',
#   u'r&b',
#   u'rap',
#   u'southern hip hop',
#   u'urban contemporary'],
#  [u'crunk',
#   u'dirty south rap',
#   u'dirty texas rap',
#   u'gangster rap',
#   u'memphis hip hop',
#   u'southern hip hop'],
#  [],
#  [u'chicano rap',
#   u'crunk',
#   u'dirty south rap',
#   u'gangster rap',
#   u'hyphy',
#   u'pop rap',
#   u'southern hip hop',
#   u'trap music'],
#  [u'crunk',
#   u'dirty south rap',
#   u'pop rap',
#   u'southern hip hop',
#   u'trap music'],
#  [u'deep east coast hip hop', u'hardcore hip hop'],
#  [u'dance pop', u'hip pop', u'r&b', u'urban contemporary'],
#  [u'crunk',
#   u'dirty south rap',
#   u'east coast hip hop',
#   u'hardcore hip hop',
#   u'hip hop',
#   u'hip pop',
#   u'new jack swing',
#   u'old school hip hop',
#   u'pop rap',
#   u'r&b',
#   u'rap',
#   u'southern hip hop',
#   u'urban contemporary'],
#  [u'crunk',
#   u'dirty south rap',
#   u'gangster rap',
#   u'hardcore hip hop',
#   u'hip hop',
#   u'hip pop',
#   u'pop rap',
#   u'rap',
#   u'trap music'],
#  [u'pop rap', u'rap', u'trap music'],
#  [u'hip pop'],
#  [u'dirty south rap', u'hip pop', u'pop rap'],
#  [u'alternative hip hop',
#   u'east coast hip hop',
#   u'hardcore hip hop',
#   u'hip hop',
#   u'turntablism'],
#  [u'deep east coast hip hop'],
#  [u'dirty south rap', u'gangster rap', u'memphis hip hop', u'trap music'],
#  [u'east coast hip hop', u'hardcore hip hop'],
#  [u'banda', u'regional mexican'],
#  [u'abstract hip hop', u'underground rap'],
#  [u'electro', u'old school hip hop'],
#  [u'hyphy', u'trap music', u'west coast trap'],
#  [],
#  [],
#  [u'crunk',
#   u'dance pop',
#   u'dirty south rap',
#   u'dwn trap',
#   u'hip hop',
#   u'hip pop',
#   u'pop rap',
#   u'rap',
#   u'southern hip hop',
#   u'trap music'],
#  [],
#  [u'hyphy', u'west coast trap'],
#  [u'dirty south rap',
#   u'gangster rap',
#   u'hip hop',
#   u'indie r&b',
#   u'pop rap',
#   u'rap',
#   u'southern hip hop',
#   u'trap music'],
#  [],
#  [],
#  [u'dance pop', u'escape room', u'hip pop', u'indie r&b', u'new rave', u'pop'],
#  [u'dwn trap',
#   u'hip hop',
#   u'indie r&b',
#   u'pop rap',
#   u'rap',
#   u'southern hip hop',
#   u'trap music'],
#  [u'gangster rap', u'hyphy', u'west coast rap', u'west coast trap'],
#  [u'abstract hip hop', u'underground pop rap', u'underground rap'],
#  [u'g funk', u'gangster rap', u'hyphy', u'west coast rap', u'west coast trap'],
#  [u'dwn trap',
#   u'hip hop',
#   u'indie r&b',
#   u'pop rap',
#   u'rap',
#   u'southern hip hop',
#   u'trap music'],
#  [],
#  [u'dwn trap',
#   u'hip hop',
#   u'pop rap',
#   u'rap',
#   u'southern hip hop',
#   u'trap music'],
#  [u'chicano rap',
#   u'crunk',
#   u'dirty south rap',
#   u'g funk',
#   u'gangster rap',
#   u'hardcore hip hop',
#   u'hip hop',
#   u'hyphy',
#   u'pop rap',
#   u'rap',
#   u'southern hip hop',
#   u'west coast rap',
#   u'west coast trap'],
#  [u'crunk', u'pop rap', u'rap', u'southern hip hop', u'trap music'],
#  [u'pop rap', u'underground pop rap'],
#  [u'hardcore hip hop', u'reggae fusion'],
#  [u'rap rock'],
#  [u'alternative hip hop', u'hip hop', u'turntablism', u'underground hip hop'],
#  [],
#  [u'pop', u'post-teen pop'],
#  [u'bounce'],
#  [u'crunk',
#   u'dirty south rap',
#   u'gangster rap',
#   u'hardcore hip hop',
#   u'hip hop',
#   u'pop rap',
#   u'rap',
#   u'trap music'],
#  [u'gospel'],
#  [u'bounce',
#   u'crunk',
#   u'dirty south rap',
#   u'gangster rap',
#   u'pop rap',
#   u'rap',
#   u'southern hip hop',
#   u'trap music'],
#  [],
#  [u'east coast hip hop',
#   u'gangster rap',
#   u'hardcore hip hop',
#   u'hip hop',
#   u'old school hip hop',
#   u'rap'],
#  [u'hyphy'],
#  [],
#  [u'crunk',
#   u'dirty south rap',
#   u'gangster rap',
#   u'hardcore hip hop',
#   u'hip hop',
#   u'hip pop',
#   u'pop rap',
#   u'r&b',
#   u'rap',
#   u'southern hip hop',
#   u'trap music',
#   u'urban contemporary'],
#  [],
#  [u'alternative hip hop',
#   u'east coast hip hop',
#   u'gangster rap',
#   u'hardcore hip hop',
#   u'hip hop',
#   u'rap',
#   u'turntablism',
#   u'underground rap'],
#  [u'alternative hip hop',
#   u'east coast hip hop',
#   u'hardcore hip hop',
#   u'hip hop'],
#  [u'crunk',
#   u'deep southern trap',
#   u'deep trap',
#   u'dirty south rap',
#   u'gangster rap',
#   u'hip hop',
#   u'hyphy',
#   u'pop rap',
#   u'rap',
#   u'southern hip hop',
#   u'trap music'],
#  [u'grime'],
#  [u'deep trap', u'pop rap', u'rap', u'southern hip hop', u'trap music'],
#  [u'gangster rap', u'hip hop', u'hyphy'],
#  [u'crunk',
#   u'dirty south rap',
#   u'g funk',
#   u'gangster rap',
#   u'hardcore hip hop',
#   u'hip hop',
#   u'west coast rap',
#   u'west coast trap'],
#  [u'comic', u'nerdcore', u'steampunk'],
#  [u'hip house', u'new jack swing', u'rap'],
#  [u'christian hip hop'],
#  [u'east coast hip hop',
#   u'gangster rap',
#   u'hardcore hip hop',
#   u'hip hop',
#   u'hip pop',
#   u'new jack swing',
#   u'old school hip hop',
#   u'rap'],
#  [u'k-hop', u'korean pop'],
#  [u'gangster rap',
#   u'hardcore hip hop',
#   u'hip hop',
#   u'hyphy',
#   u'rap',
#   u'west coast rap'],
#  [u'hardcore hip hop', u'hip hop'],
#  [u'east coast hip hop',
#   u'electro',
#   u'gangster rap',
#   u'hardcore hip hop',
#   u'hip hop',
#   u'old school hip hop',
#   u'rap'],
#  [u'chanson', u'french hip hop', u'french pop', u'french reggae'],
#  [],
#  [u'madchester'],
#  [u'dwn trap',
#   u'hip hop',
#   u'pop rap',
#   u'rap',
#   u'southern hip hop',
#   u'trap music'],
#  [u'east coast hip hop', u'hip hop', u'old school hip hop'],
#  [u'chicano rap'],
#  [u'crunk',
#   u'dirty south rap',
#   u'east coast hip hop',
#   u'gangster rap',
#   u'hardcore hip hop',
#   u'hip hop',
#   u'hip pop',
#   u'pop rap',
#   u'rap',
#   u'southern hip hop',
#   u'trap music'],
#  [u'hyphy', u'west coast rap', u'west coast trap'],
#  [u'alternative hip hop',
#   u'dirty south rap',
#   u'east coast hip hop',
#   u'gangster rap',
#   u'hardcore hip hop',
#   u'hip hop',
#   u'hip pop',
#   u'pop rap',
#   u'rap',
#   u'southern hip hop'],
#  [u'dwn trap', u'rap', u'southern hip hop', u'trap music'],
#  [u'alternative hip hop',
#   u'east coast hip hop',
#   u'escape room',
#   u'hardcore hip hop',
#   u'hip hop',
#   u'rap',
#   u'underground hip hop'],
#  [u'alternative hip hop', u'hardcore hip hop', u'hip hop', u'turntablism'],
#  [u'crunk',
#   u'dirty south rap',
#   u'gangster rap',
#   u'hip pop',
#   u'southern hip hop',
#   u'trap music'],
#  [u'gangster rap', u'hardcore hip hop', u'hip hop'],
#  [u'alternative hip hop',
#   u'deep indie r&b',
#   u'deep underground hip hop',
#   u'drill',
#   u'escape room',
#   u'hip hop',
#   u'indie r&b',
#   u'pop rap',
#   u'rap',
#   u'southern hip hop',
#   u'underground hip hop'],
#  [],
#  [],
#  [u'underground hip hop'],
#  [u'crunk', u'dirty south rap', u'pop rap', u'southern hip hop'],
#  [u'dance pop', u'pop', u'pop rap', u'post-teen pop', u'tropical house'],
#  [],
#  [u'deep underground hip hop',
#   u'dwn trap',
#   u'pop rap',
#   u'rap',
#   u'underground pop rap'],
#  [u'dwn trap',
#   u'gangster rap',
#   u'pop rap',
#   u'rap',
#   u'southern hip hop',
#   u'trap music',
#   u'underground hip hop'],
#  [u'deep underground hip hop', u'underground hip hop'],
#  [u'chamber pop',
# ...
#  [],
#  [u'crunk',
#   u'deep southern trap',
#   u'deep trap',
#   u'dirty south rap',
#   u'gangster rap',
#   u'pop rap',
#   u'rap',
#   u'southern hip hop',
#   u'trap music'],
#  [u'dance pop', u'latin', u'pop', u'pop rap'],
#  [u'alternative hip hop',
#   u'hardcore hip hop',
#   u'turntablism',
#   u'underground hip hop',
#   u'underground rap'],
#  [],
#  [u'crunk',
#   u'dance pop',
#   u'deep southern trap',
#   u'deep trap',
#   u'dirty south rap',
#   u'dwn trap',
#   u'gangster rap',
#   u'hip hop',
#   u'hip pop',
#   u'pop rap',
#   u'r&b',
#   u'rap',
#   u'southern hip hop',
#   u'trap music',
#   u'urban contemporary'],
#  [u'kiwi rock', u'polynesian pop'],
#  [u'east coast hip hop', u'hardcore hip hop', u'hip hop', u'rap'],
#  [u'dwn trap', u'pop rap', u'rap', u'southern hip hop', u'trap music'],
#  [],
#  [],
#  [u'alternative hip hop',
#   u'east coast hip hop',
#   u'hardcore hip hop',
#   u'hip hop',
#   u'turntablism'],
#  [u'alternative hip hop', u'hardcore hip hop', u'hip hop', u'turntablism'],
#  [u'crunk',
#   u'deep trap',
#   u'deep underground hip hop',
#   u'dirty south rap',
#   u'dwn trap',
#   u'gangster rap',
#   u'hyphy',
#   u'pop rap',
#   u'rap',
#   u'southern hip hop',
#   u'trap music',
#   u'west coast trap'],
#  [u'big beat', u'breakbeat', u'electronic', u'hardcore techno'],
#  [u'grime', u'house', u'pop', u'uk garage'],
#  [u'crunk',
#   u'deep southern trap',
#   u'deep trap',
#   u'dirty south rap',
#   u'gangster rap',
#   u'memphis hip hop',
#   u'pop rap',
#   u'rap',
#   u'southern hip hop',
#   u'trap music'],
#  [u'deep latin hip hop', u'detroit hip hop', u'gangster rap', u'hip hop'],
#  [u'horrorcore', u'rap rock'],
#  [u'dance pop', u'k-hop', u'k-pop'],
#  [u'dirty south rap',
#   u'dwn trap',
#   u'gangster rap',
#   u'hip hop',
#   u'indie r&b',
#   u'pop rap',
#   u'rap',
#   u'southern hip hop',
#   u'trap music',
#   u'underground hip hop'],
#  [u'alternative hip hop',
#   u'east coast hip hop',
#   u'hardcore hip hop',
#   u'hip hop',
#   u'neo soul',
#   u'pop rap',
#   u'rap',
#   u'southern hip hop'],
#  [u'deep trap',
#   u'dirty south rap',
#   u'dwn trap',
#   u'gangster rap',
#   u'hip hop',
#   u'pop rap',
#   u'rap',
#   u'southern hip hop',
#   u'trap music'],
#  [],
#  [u'east coast hip hop', u'hip hop', u'hip pop', u'hollywood'],
#  [u'hip pop'],
#  [u'k-hop', u'korean pop'],
#  [],
#  [u'outer hip hop', u'underground rap'],
#  [u'abstract hip hop', u'underground rap'],
#  [u'alternative hip hop',
#   u'east coast hip hop',
#   u'hardcore hip hop',
#   u'hip hop',
#   u'underground rap'],
#  [u'alternative hip hop',
#   u'dirty south rap',
#   u'east coast hip hop',
#   u'gangster rap',
#   u'hardcore hip hop',
#   u'hip hop',
#   u'pop rap',
#   u'rap',
#   u'southern hip hop',
#   u'underground hip hop'],
#  [u'hardcore hip hop', u'hip pop'],
#  [u'east coast hip hop', u'hardcore hip hop', u'hip hop', u'turntablism'],
#  [u'alternative hip hop',
#   u'east coast hip hop',
#   u'gangster rap',
#   u'hardcore hip hop',
#   u'hip hop',
#   u'rap',
#   u'southern hip hop'],
#  [],
#  [u'dwn trap'],
#  [],
#  [u'g funk', u'gangster rap', u'hyphy'],
#  [u'alternative hip hop'],
#  [u'alternative hip hop',
#   u'gangster rap',
#   u'hardcore hip hop',
#   u'hip hop',
#   u'turntablism',
#   u'underground rap'],
#  [u'crunk',
#   u'deep pop r&b',
#   u'dirty south rap',
#   u'hip pop',
#   u'pop rap',
#   u'southern hip hop'],
#  [u'crunk',
#   u'dirty south rap',
#   u'gangster rap',
#   u'pop rap',
#   u'rap',
#   u'southern hip hop',
#   u'trap music'],
#  [u'alternative r&b',
#   u'dance pop',
#   u'deep pop r&b',
#   u'hip pop',
#   u'pop',
#   u'pop rap',
#   u'r&b',
#   u'slow game',
#   u'southern hip hop',
#   u'urban contemporary'],
#  [u'g funk', u'hyphy'],
#  [],
#  [u'g funk', u'gangster rap', u'hip hop', u'hyphy', u'rap', u'west coast rap'],
#  [u'electro', u'old school hip hop'],
#  [u'pop rap'],
#  [u'crunk',
#   u'dirty south rap',
#   u'pop rap',
#   u'rap',
#   u'southern hip hop',
#   u'trap music'],
#  [],
#  [u'deep flow'],
#  [u'alternative hip hop',
#   u'dirty south rap',
#   u'east coast hip hop',
#   u'gangster rap',
#   u'hardcore hip hop',
#   u'hip hop',
#   u'hip pop',
#   u'pop rap',
#   u'rap',
#   u'southern hip hop'],
#  [u'underground rap'],
#  [u'escape room', u'hip pop'],
#  [u'alternative hip hop', u'hardcore hip hop', u'underground rap'],
#  [u'hip hop', u'hip pop', u'r&b', u'urban contemporary'],
#  [u'alternative hip hop', u'dirty south rap', u'hip hop', u'pop rap'],
#  [u'crunk',
#   u'deep southern trap',
#   u'deep trap',
#   u'dirty south rap',
#   u'gangster rap',
#   u'hip pop',
#   u'pop rap',
#   u'rap',
#   u'southern hip hop',
#   u'trap music'],
#  [u'deep trap',
#   u'dirty south rap',
#   u'dwn trap',
#   u'gangster rap',
#   u'hip hop',
#   u'pop rap',
#   u'rap',
#   u'southern hip hop',
#   u'trap music'],
#  [u'deep southern trap',
#   u'deep trap',
#   u'dwn trap',
#   u'rap',
#   u'southern hip hop',
#   u'trap music',
#   u'underground hip hop'],
#  [u'g funk', u'gangster rap', u'hyphy'],
#  [u'west coast trap'],
#  [u'crunk',
#   u'dance pop',
#   u'dirty south rap',
#   u'dwn trap',
#   u'gangster rap',
#   u'hip hop',
#   u'pop rap',
#   u'rap',
#   u'southern hip hop',
#   u'trap music'],
#  [u'deep pop r&b', u'r&b'],
#  [u'deep underground hip hop',
#   u'dwn trap',
#   u'hip hop',
#   u'pop rap',
#   u'rap',
#   u'southern hip hop',
#   u'trap music',
#   u'underground hip hop',
#   u'underground pop rap'],
#  [u'deep underground hip hop',
#   u'dirty south rap',
#   u'gangster rap',
#   u'pop rap',
#   u'southern hip hop',
#   u'trap music',
#   u'underground pop rap'],
#  [u'alternative hip hop',
#   u'electronic',
#   u'hip hop',
#   u'nu jazz',
#   u'trip hop',
#   u'turntablism'],
#  [u'abstract hip hop'],
#  [u'alternative hip hop', u'hardcore hip hop', u'underground hip hop'],
#  [u'deep underground hip hop',
#   u'rap',
#   u'underground hip hop',
#   u'underground pop rap'],
#  [u'crunk',
#   u'deep southern trap',
#   u'deep trap',
#   u'dirty south rap',
#   u'dwn trap',
#   u'gangster rap',
#   u'pop rap',
#   u'rap',
#   u'southern hip hop',
#   u'trap music'],
#  [u'classic funk rock', u'funk', u'post-disco', u'quiet storm'],
#  [],
#  [],
#  [u'big beat',
#   u'breakbeat',
#   u'electronic',
#   u'grime',
#   u'hip hop',
#   u'ninja',
#   u'nu jazz',
#   u'trip hop',
#   u'turntablism',
#   u'uk garage',
#   u'uk hip hop'],
#  [u'crunk',
#   u'dirty south rap',
#   u'pop rap',
#   u'rap',
#   u'southern hip hop',
#   u'trap music'],
#  [u'crunk',
#   u'dirty south rap',
#   u'pop rap',
#   u'rap',
#   u'southern hip hop',
#   u'trap music'],
#  [u'deep trap', u'dwn trap', u'trap music'],
#  [u'electro', u'hip hop', u'old school hip hop'],
#  [u'alternative hip hop',
#   u'detroit hip hop',
#   u'dirty south rap',
#   u'gangster rap',
#   u'hardcore hip hop',
#   u'hip hop',
#   u'pop rap',
#   u'rap',
#   u'southern hip hop',
#   u'underground hip hop'],
#  [u'antiviral pop', u'comic'],
#  [u'hyphy', u'west coast trap'],
#  [u'bmore', u'escape room'],
#  [u'alternative hip hop',
#   u'east coast hip hop',
#   u'gangster rap',
#   u'hardcore hip hop',
#   u'hip hop'],
#  [],
#  [],
#  [],
#  [],
#  [u'alternative hip hop',
#   u'east coast hip hop',
#   u'hardcore hip hop',
#   u'hip hop',
#   u'turntablism'],
#  [u'abstract hip hop', u'underground rap'],
#  [u'abstract hip hop', u'alternative hip hop', u'underground rap'],
#  [u'deep pop r&b',
#   u'dwn trap',
#   u'hyphy',
#   u'pop rap',
#   u'rap',
#   u'southern hip hop',
#   u'trap music'],
#  [u'alternative hip hop',
#   u'hardcore hip hop',
#   u'hip hop',
#   u'pop rap',
#   u'southern hip hop'],
#  [u'g funk'],
#  [u'pop rap', u'underground pop rap'],
#  [u'k-pop', u'korean pop'],
#  [u'hyphy', u'west coast trap'],
#  [u'afrobeats', u'azonto', u'azontobeats', u'hiplife'],
#  [u'hardcore hip hop'],
#  [u'dwn trap', u'pop rap', u'rap', u'southern hip hop', u'trap music'],
#  [u'crunk',
#   u'deep southern trap',
#   u'dirty south rap',
#   u'gangster rap',
#   u'hardcore hip hop',
#   u'hip hop',
#   u'pop rap',
#   u'rap',
#   u'southern hip hop',
#   u'trap music'],
#  [u'dwn trap',
#   u'hip hop',
#   u'indie r&b',
#   u'pop rap',
#   u'rap',
#   u'southern hip hop',
#   u'trap music',
#   u'underground hip hop'],
#  [u'east coast hip hop',
#   u'electro',
#   u'gangster rap',
#   u'hardcore hip hop',
#   u'hip hop',
#   u'old school hip hop',
#   u'rap'],
#  [],
#  [u'contemporary country',
#   u'country',
#   u'country christmas',
#   u'country road',
#   u'modern country rock',
#   u'pop christmas'],
#  [],
#  [u'kiwi rock', u'polynesian pop'],
#  [u'deep trap', u'trap music'],
#  [u'grime'],
#  [u'deep trap', u'dwn trap', u'trap music', u'underground hip hop'],
#  [u'crunk',
#   u'dance pop',
#   u'dirty south rap',
#   u'east coast hip hop',
#   u'hip hop',
#   u'hip pop',
#   u'pop',
#   u'pop rap',
#   u'r&b',
#   u'rap',
#   u'trap music'],
#  [u'alternative hip hop',
#   u'gangster rap',
#   u'hardcore hip hop',
#   u'hip hop',
#   u'underground rap'],
#  [u'deep g funk', u'g funk', u'hyphy'],
#  [],
#  [u'christian hip hop'],
#  [],
#  [u'hardcore hip hop'],
#  [u'deep trap'],
#  [u'g funk', u'gangster rap', u'west coast rap'],
#  [u'hyphy', u'west coast trap'],
#  [u'horrorcore'],
#  [u'gangster rap', u'hardcore hip hop', u'hip hop'],
#  [u'crunk', u'dirty south rap', u'hip pop', u'pop rap', u'southern hip hop'],
#  [u'crunk',
#   u'deep trap',
#   u'dirty south rap',
#   u'gangster rap',
#   u'pop rap',
#   u'rap',
#   u'southern hip hop',
#   u'trap music'],
#  [u'crunk', u'hardcore hip hop', u'hip hop', u'southern hip hop'],
#  [u'ambeat', u'j-rap'],
#  [u'christian hip hop'],
#  [],
#  [u'funk', u'new orleans blues'],
#  [],
#  [u'pop rap', u'underground pop rap'],
#  [u'deep southern trap',
#   u'deep trap',
#   u'drill',
#   u'dwn trap',
#   u'gangster rap',
#   u'rap',
#   u'southern hip hop',
#   u'trap music'],
#  [u'hardcore hip hop', u'hip hop'],
#  [u'dirty south rap',
#   u'gangster rap',
#   u'hardcore hip hop',
#   u'hip hop',
#   u'hip pop',
#   u'pop rap',
#   u'rap',
#   u'southern hip hop',
#   u'trap music'],
#  [],
#  [u'crunk',
#   u'deep southern trap',
#   u'dirty south rap',
#   u'gangster rap',
#   u'hip pop',
#   u'pop rap',
#   u'southern hip hop',
#   u'trap music',
#   u'wrestling'],
#  [],
#  [u'deep g funk', u'gangster rap'],
#  [u'gangster rap', u'hip hop', u'miami bass', u'old school hip hop', u'rap'],
#  [u'gangster rap', u'hip hop', u'rap', u'west coast rap'],
#  [u'deep underground hip hop',
#   u'trap music',
#   u'underground hip hop',
#   u'west coast trap'],
#  [u'grime', u'uk hip hop'],
#  [u'alternative hip hop', u'hardcore hip hop', u'hip hop'],
#  [u'deep trap'],
#  [u'dirty south rap', u'neo soul'],
#  [u'crunk',
#   u'deep trap',
#   u'dirty south rap',
#   u'gangster rap',
#   u'pop rap',
#   u'rap',
#   u'southern hip hop',
#   u'trap music'],
#  [u'alternative hip hop',
#   u'dirty south rap',
#   u'east coast hip hop',
#   u'gangster rap',
#   u'hardcore hip hop',
#   u'hip hop',
#   u'old school hip hop',
#   u'pop rap',
#   u'rap',
#   u'southern hip hop'],
#  [],
#  [u'crunk',
#   u'deep southern trap',
#   u'deep trap',
#   u'dirty south rap',
#   u'dwn trap',
#   u'gangster rap',
#   u'hip hop',
#   u'pop rap',
#   u'rap',
#   u'southern hip hop',
#   u'trap music'],
#  [u'underground hip hop'],
#  [],
#  [u'alternative hip hop',
#   u'dirty south rap',
#   u'hip hop',
#   u'pop rap',
#   u'rap',
#   u'southern hip hop',
#   u'trap music',
#   u'underground hip hop',
#   u'west coast trap'],
#  [u'antiviral pop',
#   u'deep chiptune',
#   u'otacore',
#   u'scorecore',
#   u'video game music'],
#  [u'hardcore hip hop'],
#  [u'g funk',
#   u'gangster rap',
#   u'hip hop',
#   u'pop christmas',
#   u'pop rap',
#   u'rap',
#   u'southern hip hop',
#   u'west coast rap'],
#  [u'crunk',
#   u'deep pop r&b',
#   u'deep southern trap',
#   u'deep trap',
#   u'dwn trap',
#   u'gangster rap',
#   u'memphis hip hop',
#   u'rap',
#   u'southern hip hop',
#   u'trap music'],
#  [],
#  [],
#  [u'abstract hip hop', u'underground rap'],
#  [u'deep trap',
#   u'dwn trap',
#   u'rap',
#   u'southern hip hop',
#   u'trap music',
#   u'underground hip hop'],
#  [],
#  [u'g funk', u'gangster rap', u'hip hop', u'hyphy', u'west coast rap'],
#  [u'crunk',
#   u'dance pop',
#   u'dirty south rap',
#   u'dwn trap',
#   u'gangster rap',
#   u'hip hop',
#   u'hip pop',
#   u'pop rap',
#   u'rap',
#   u'southern hip hop',
#   u'trap music'],
#  [u'bounce',
#   u'crunk',
#   u'deep southern trap',
#   u'dirty south rap',
#   u'gangster rap',
#   u'southern hip hop',
#   u'trap music'],
#  [u'chicano rap', u'latin hip hop'],
#  [u'pub rock', u'roots rock', u'southern rock'],
#  [u'alternative hip hop', u'hip hop', u'trap music', u'underground hip hop'],
#  [u'electro', u'hardcore hip hop', u'hip hop', u'old school hip hop', u'rap'],
#  [u'chicano rap',
#   u'crunk',
#   u'dirty south rap',
#   u'g funk',
#   u'gangster rap',
#   u'hardcore hip hop',
#   u'hip hop',
#   u'hyphy',
#   u'rap',
#   u'west coast rap',
#   u'west coast trap'],
#  [u'gangster rap'],
#  [u'electro', u'hip hop', u'old school hip hop'],
#  [u'comic', u'pop rap', u'underground pop rap'],
#  [],
#  [u'alternative hip hop',
#   u'crunk',
#   u'dirty south rap',
#   u'hip hop',
#   u'pop rap',
#   u'rap',
#   u'southern hip hop',
#   u'trap music',
#   u'underground hip hop',
#   u'west coast trap'],
#  [u'crunk',
#   u'deep southern trap',
#   u'deep trap',
#   u'dirty south rap',
#   u'gangster rap',
#   u'rap',
#   u'southern hip hop',
#   u'trap music'],
#  [u'crunk',
#   u'dirty south rap',
#   u'gangster rap',
#   u'pop rap',
#   u'southern hip hop'],
#  [],
#  [u'alternative hip hop',
#   u'hardcore hip hop',
#   u'hip hop',
#   u'southern hip hop',
#   u'underground hip hop'],
#  [u'old school hip hop'],
#  [u'hyphy', u'west coast trap'],
#  [u'dirty south rap'],
#  [u'hip hop', u'old school hip hop'],
#  [u'hardcore hip hop', u'hip hop'],
#  [],
#  [],
#  [u'detroit hip hop'],
#  [u'crunk',
#   u'dirty south rap',
#   u'east coast hip hop',
#   u'gangster rap',
#   u'hardcore hip hop',
#   u'hip hop',
#   u'hip pop',
#   u'pop rap',
#   u'rap',
#   u'southern hip hop',
#   u'trap music'],
#  [u'ambeat'],
#  [u'chicano rap',
#   u'dirty south rap',
#   u'g funk',
#   u'gangster rap',
#   u'hip hop',
#   u'hyphy',
#   u'west coast rap',
#   u'west coast trap'],
#  [],
#  [],
#  [u'crunk',
#   u'dirty south rap',
#   u'hip hop',
#   u'hip pop',
#   u'pop rap',
#   u'rap',
#   u'southern hip hop',
#   u'trap music'],
#  [],
#  [],
#  [u'deep indie r&b',
#   u'escape room',
#   u'indie r&b',
#   u'neo soul',
#   u'r&b',
#   u'rap',
#   u'underground hip hop'],
#  [u'east coast hip hop', u'electro', u'hip hop', u'old school hip hop'],
#  [u'acoustic blues',
#   u'blues',
#   u'blues-rock',
#   u'chicago blues',
#   u'country blues',
#   u'delta blues',
#   u'electric blues',
#   u'harmonica blues',
#   u'jazz blues',
#   u'jump blues',
#   u'louisiana blues',
#   u'memphis blues',
#   u'new orleans blues',
#   u'piano blues',
#   u'piedmont blues',
#   u'soul blues',
#   u'swamp blues',
#   u'texas blues',
#   u'traditional blues'],
#  [u'hyphy', u'west coast trap'],
#  [u'crunk',
#   u'dance pop',
#   u'dirty south rap',
#   u'dwn trap',
#   u'gangster rap',
#   u'hip hop',
#   u'hip pop',
#   u'pop',
#   u'pop rap',
#   u'r&b',
#   u'rap',
#   u'southern hip hop',
#   u'trap music',
#   u'urban contemporary'],
#  [u'dwn trap', u'pop rap', u'rap', u'southern hip hop', u'trap music'],
#  [u'pop rap', u'underground pop rap'],
#  [u'crunk',
#   u'dance pop',
#   u'dirty south rap',
#   u'dwn trap',
#   u'gangster rap',
#   u'hip hop',
#   u'pop',
#   u'pop rap',
#   u'r&b',
#   u'rap',
#   u'southern hip hop',
#   u'trap music'],
#  [u'album rock',
#   u'blues-rock',
#   u'classic rock',
#   u'electric blues',
#   u'hard rock',
#   u'mellow gold',
#   u'metal',
#   u'rock',
#   u'roots rock',
#   u'soft rock',
#   u'texas blues'],
#  [],
#  [u'dance pop', u'k-hop', u'k-pop', u'korean pop'],
#  [u'alternative hip hop',
#   u'dirty south rap',
#   u'east coast hip hop',
#   u'hardcore hip hop',
#   u'hip hop',
#   u'neo soul',
#   u'pop rap',
#   u'rap',
#   u'southern hip hop'],
#  [u'redneck'],
#  [u'pop rap'],
#  [],
#  [u'dance pop', u'deep pop r&b', u'hip pop', u'r&b', u'urban contemporary'],
#  [u'crunk',
#   u'dirty south rap',
#   u'gangster rap',
#   u'hip hop',
#   u'pop rap',
#   u'rap',
#   u'southern hip hop',
#   u'trap music'],
#  [u'ccm',
#   u'christian alternative rock',
#   u'christian hip hop',
#   u'christian rock'],
#  [u'slow game'],
#  [u'hardcore hip hop'],
#  [u'crunk', u'dirty south rap', u'gangster rap', u'southern hip hop'],
#  [u'alternative hip hop', u'hardcore hip hop', u'underground rap'],
#  [u'alternative hip hop', u'deep indie r&b', u'indie jazz', u'neo soul'],
#  [u'dance pop',
#   u'deep pop r&b',
#   u'hip pop',
#   u'indie r&b',
#   u'neo soul',
#   u'r&b',
#   u'urban contemporary'],
#  [u'g funk'],
#  [],
#  [],
#  [u'indie r&b', u'pop rap', u'rap'],
#  [],
#  [u'afrobeats', u'azonto', u'azontobeats'],
#  [u'dance pop',
#   u'dirty south rap',
#   u'hip hop',
#   u'hip pop',
#   u'pop',
#   u'pop rap',
#   u'post-teen pop',
#   u'r&b',
#   u'rap',
#   u'southern hip hop',
#   u'urban contemporary'],
#  [],
#  ...]

# %%
song_dev.find_one({'genius_data': {'$exists': True, '$nin': ['No Result','AttributeError', 'TypeError']}})
# Out:
# {u'_id': ObjectId('5823c40be228c38897ffa947'),
#  u'audio_features': [{u'acousticness': 0.129,
#    u'analysis_url': u'https://api.spotify.com/v1/audio-analysis/6s76y7zMZ82FicL21wuhaj',
#    u'danceability': 0.798,
#    u'duration_ms': 214167,
#    u'energy': 0.447,
#    u'id': u'6s76y7zMZ82FicL21wuhaj',
#    u'instrumentalness': 0,
#    u'key': 5,
#    u'liveness': 0.087,
#    u'loudness': -12.141,
#    u'mode': 0,
#    u'speechiness': 0.389,
#    u'tempo': 143.911,
#    u'time_signature': 4,
#    u'track_href': u'https://api.spotify.com/v1/tracks/6s76y7zMZ82FicL21wuhaj',
#    u'type': u'audio_features',
#    u'uri': u'spotify:track:6s76y7zMZ82FicL21wuhaj',
#    u'valence': 0.495}],
#  u'genius_data': {u'highlights': [],
#   u'index': u'song',
#   u'result': {u'annotation_count': 31,
#    u'api_path': u'/songs/211725',
#    u'full_title': u'My Activator by\xa0100s',
#    u'header_image_thumbnail_url': u'https://s3.amazonaws.com/rapgenius/a4228093635_10.jpg',
#    u'header_image_url': u'https://s3.amazonaws.com/rapgenius/a4228093635_10.jpg',
#    u'id': 211725,
#    u'lyrics_owner_id': 275598,
#    u'path': u'/100s-my-activator-lyrics',
#    u'primary_artist': {u'api_path': u'/artists/49243',
#     u'header_image_url': u'https://s3.amazonaws.com/rapgenius/100s.jpeg',
#     u'id': 49243,
#     u'image_url': u'https://s3.amazonaws.com/rapgenius/100s.jpeg',
#     u'iq': 145,
#     u'is_meme_verified': False,
#     u'is_verified': False,
#     u'name': u'100s',
#     u'url': u'http://genius.com/artists/100s'},
#    u'pyongs_count': 1,
#    u'song_art_image_thumbnail_url': u'https://s3.amazonaws.com/rapgenius/a4228093635_10.jpg',
#    u'stats': {u'hot': False, u'unreviewed_annotations': 23},
#    u'title': u'My Activator',
#    u'url': u'http://genius.com/100s-my-activator-lyrics'},
#   u'type': u'song'},
#  u'html': u'\n\n\n\n\n\n//<![CDATA[\nvar _sf_startpt=(new Date()).getTime();\n//]]>\n\n100s \u2013 My Activator Lyrics | Genius Lyrics\n\n\n\n\n\n\n\n\n\n\n\n\n\n  var CURRENT_USER = null;\n  var CANONICAL_DOMAIN = "genius.com";\n  var CANONICAL_DOMAIN_PARTS_LENGTH = 2;\n  var CURRENT_CHANNEL = "rap";\n  var CURRENT_TAG = {"tag":{"always_allow_personal_annotation":null,"beefy":true,"created_at":"2014-05-15T20:10:15Z","deleted_at":null,"description":"Rap Genius is dedicated to crowd-sourced (and [artist](http://rapgenius.com/Nas)/[producer](http://rapgenius.com/youngchopbeatz)-sourced) annotation of rap lyrics/[beats](/tags/producer-genius), from [\\"Rapper\'s Delight\\"](http://rapgenius.com/Sugar-hill-gang-rappers-delight-lyrics) to [*To Pimp A Butterfly.*](http://genius.com/Kendrick-lamar-to-pimp-a-butterfly-album-art-track-list-lyrics) Fan favorites [Rap Stats](http://genius.com/rapstats) & [The Rap Map](http://genius.com/map/) also call Rap Genius home. \\r\\n\\r\\nFind out all the latest on [Twitter](https://twitter.com/RapGenius) and [Facebook](https://www.facebook.com/RapGenius)","designation":"featured_music","google_analytics_table_id":"ga:88245212","id":1434,"image_url":"https://images.rapgenius.com/922b8f934a36ecffb07c4cd83ecfbf2d.600x600x1.png","implied_channel_id":1,"languages_store":{},"logical_name":"rap","name":"Rap Genius","slug":"rap","taggings_count":426863,"twitter_name":"RapGenius","updated_at":"2016-10-17T12:34:28Z"}};\n  var TRACKING_DATA = {"Song ID":211725,"Title":"My Activator","Primary Artist":"100s","Primary Artist ID":49243,"Primary Album":"Ice Cold Perm","Primary Album ID":33281,"Primary Tag":"rap","Primary Tag ID":1434,"Has Relevant Videos?":true,"Music?":true,"Annotatable Type":"Song","Annotatable ID":211725,"featured_video":false,"cohort_ids":[],"has_verified_callout":false,"has_featured_annotation":true,"created_at":"2013-08-29T16:04:21Z","created_month":"2013-08-01","created_year":2013,"song_tier":"E","Has Recirculated Articles":false};\n  var VALID_SUBDOMAINS = ["x","screen","rap","history","sports","rock","country","r-b","lit","pop","news","meta","tech","law"];\n  var EMBEDLY_KEY = "fc778e44915911e088ae4040f9f86dcd";\n  var MOBILE_DEVICE = false;\n  var APP_CONFIG = {"env":"production","api_root_url":"/api","facebook_app_id":"265539304824","facebook_opengraph_api_version":"2.5","pusher_app_key":"6d893fcc6a0c695853ac","embedly_key":"fc778e44915911e088ae4040f9f86dcd","app_store_url":"https://itunes.apple.com/us/app/genius-by-rap-genius-search/id709482991?ls=1&mt=8","play_store_url":"https://play.google.com/store/apps/details?id=com.genius.android","soundcloud_client_id":"632c544d1c382f82526f369877aab5c0","annotator_context_length":32,"comment_reasons":[{"_type":"comment_reason","context_url":"http://genius.com/8846441/Genius-how-genius-works/More-on-annotations","display_character":"R","handle":"Restates the line","id":1,"name":"restates-the-line","raw_name":"restates the line","requires_body":false,"slug":"restates_the_line"},{"_type":"comment_reason","context_url":"http://genius.com/8846441/Genius-how-genius-works/More-on-annotations","display_character":"S","handle":"It\u2019s a stretch","id":2,"name":"its-a-stretch","raw_name":"it\u2019s a stretch","requires_body":false,"slug":"its_a_stretch"},{"_type":"comment_reason","context_url":"http://genius.com/8846441/Genius-how-genius-works/More-on-annotations","display_character":"M","handle":"Missing something","id":3,"name":"missing-something","raw_name":"missing something","requires_body":false,"slug":"missing_something"},{"_type":"comment_reason","context_url":"http://genius.com/8846441/Genius-how-genius-works/More-on-annotations","display_character":"\u2026","handle":"Other","id":4,"name":"other","raw_name":"other","requires_body":true,"slug":"other"}],"filepicker_api_key":"Ar03MDs73TQm241ZgLwfjz","filepicker_policy":"eyJleHBpcnkiOiIyMzIyMjM4OTI3IiwiY2FsbCI6WyJwaWNrIiwicGlja0FuZFN0b3JlIiwicmVhZCIsInN0b3JlIiwic3RhdCJdfQ==","filepicker_signat ...
#  u'lyrics': u'\n\n"Back up!"\n"Back up, back up, back up..."\n"Okay now, just, just put the activator down."\n"Where were you the day Cookie Head got killed?"\n"I was at the hair salon man, I was getting my curl done, I was there all day."\n"Where?"\n"Oh okay, I wasn\'t there all day man, I [?] on Crenshaw, I bought me some hair care products man. I got some activator. Some glycerine. And some curl activator."\n"I ain\'t never went out to the beach."\n\n[Verse 1]\nMake your bitch wanna have a nigga slide through and put dick on her\nWanna dip with a nigga take a trip with a nigga, what, you ain\'t know you was a flip to a nigga, huh?\nI\'ma let my soul glow in a black volvo and my teeth shine like a chrome .44\nDon\'t tell a nigga nothing that he don\'t know, with a mouthpiece that could put you on a ho stroll\nThought you was the nigga til you a nigga huh, now you thinking about what you told them hoes\nWhen You was all up in they bed, pillow talking and hating, throwing all types of salt on my operation\nAte a bitch, get it then play the bitch\nBut she live in section 8 with her brother sister momma and her uncle trying to hustle\nDo I save the bitch? Do I lace the bitch?\nDo I pump her veins with my activator?\nDo I call her now? Do I call her later?\nDo I leave her hanging like "bitch I\'m through"? Do I leave her insecure like "what I do?"\nWe should flip for it, heads or tails, what I choose?\nMomma never thought I was a bad kid, but I got a lot of tales for the grandkids\nI must say, players only live once,\nIs you bout it?\nLet a real nigga reroute it\nMake a nigga wanna ask questions like "who that is?" "What he do?"\n"Do you know that nigga? Did you fuck that nigga?" Cause...\nIf so, then bitch we through\n\n[Hook]\nMy activator, ho, my activator (x3)\nDon\'t touch my activator, no, cold game, don\'t hate the player\nMy activator, my activator (x3)\nFuck all them perpetrators, in the end all I got is my activator\n\n[Verse 2]\nHow that nigga got all that but ain\'t working? How that nigga got all that but ain\'t serving?\nTold him it\'s the activator nigga, do you need some? I might have some for you\nHow to make a motherfucker hate yo shit, then how to make a motherfucker play yo shit, and how to make a motherfucker take yo shit, date yo shit, pay yo shit\nThat activator charm, and you know that!\nTell that ho to set alarm, if you wanna put a diamonds in the charm\nMake a nigga stop like, "Oh that\'s you? "Unloading all your cashews, in a bitch with benefits and a back tattoo?"\n"Can you make a bitch cum with your dick and your tongue?" That\'s the question dude\n"Can you tell that bitch that shes the only one and you was never with that other bitch and have her never question you?"\nBe smooth with it, no details\nSome niggas flip a whole clique of bitches then go run they mouth like a female\nThat ain\'t P, therefore that ain\'t me\n"Do you smile when you see her, kiss and hug that bitch?"\n"When your slipping, when she\'s slipping, would you love that bitch?" My nigga you fucking up\nGotta feel em out\nBut if she left yo ass, you would call the ho pouring your feelings out\n\n[Hook]\n\n[End]\n\n',
#  u'musician_id': ObjectId('58212da6e228c35b02d5c030'),
#  u'process_time': 1.12,
#  u'spotify_album_id': u'6yuV1cqKFzhlezMdO19aZS',
#  u'spotify_artist_id': u'7al781lgi4qF927X0fFVXj',
#  u'spotify_track_data': {u'artists': [{u'external_urls': {u'spotify': u'https://open.spotify.com/artist/7al781lgi4qF927X0fFVXj'},
#     u'href': u'https://api.spotify.com/v1/artists/7al781lgi4qF927X0fFVXj',
#     u'id': u'7al781lgi4qF927X0fFVXj',
#     u'name': u'100s',
#     u'type': u'artist',
#     u'uri': u'spotify:artist:7al781lgi4qF927X0fFVXj'}],
#   u'available_markets': [u'AD',
#    u'AR',
#    u'AT',
#    u'AU',
#    u'BE',
#    u'BG',
#    u'BO',
#    u'BR',
#    u'CA',
#    u'CH',
#    u'CL',
#    u'CO',
#    u'CR',
#    u'CY',
#    u'CZ',
#    u'DE',
#    u'DK',
#    u'DO',
#    u'EC',
#    u'EE',
#    u'ES',
#    u'FI',
#    u'FR',
#    u'GB',
#    u'GR',
#    u'GT',
#    u'HK',
#    u'HN',
#    u'HU',
#    u'ID',
#    u'IE',
#    u'IS',
#    u'IT',
#    u'JP',
#    u'LI',
#    u'LT',
#    u'LU',
#    u'LV',
#    u'MC',
#    u'MT',
#    u'MX',
#    u'MY',
#    u'NI',
#    u'NL',
#    u'NO',
#    u'NZ',
#    u'PA',
#    u'PE',
#    u'PH',
#    u'PL',
#    u'PT',
#    u'PY',
#    u'SE',
#    u'SG',
#    u'SK',
#    u'SV',
#    u'TR',
#    u'TW',
#    u'US',
#    u'UY'],
#   u'disc_number': 1,
#   u'duration_ms': 214166,
#   u'explicit': True,
#   u'external_urls': {u'spotify': u'https://open.spotify.com/track/6s76y7zMZ82FicL21wuhaj'},
#   u'href': u'https://api.spotify.com/v1/tracks/6s76y7zMZ82FicL21wuhaj',
#   u'id': u'6s76y7zMZ82FicL21wuhaj',
#   u'name': u'My Activator',
#   u'preview_url': u'https://p.scdn.co/mp3-preview/a2b4807709adbce105c39e7f33953776b4f43285',
#   u'track_number': 1,
#   u'type': u'track',
#   u'uri': u'spotify:track:6s76y7zMZ82FicL21wuhaj'}}

# %%
album_dev.find_one({})
# Out:
# {u'_id': ObjectId('5823c406e228c38897ffa920'),
#  u'musician_id': ObjectId('58212da6e228c35b02d5c02f'),
#  u'spotify_album_data': {u'album_type': u'single',
#   u'artists': [{u'external_urls': {u'spotify': u'https://open.spotify.com/artist/2KgSliKOckorQuEHjAa15V'},
#     u'href': u'https://api.spotify.com/v1/artists/2KgSliKOckorQuEHjAa15V',
#     u'id': u'2KgSliKOckorQuEHjAa15V',
#     u'name': u'Fang',
#     u'type': u'artist',
#     u'uri': u'spotify:artist:2KgSliKOckorQuEHjAa15V'},
#    {u'external_urls': {u'spotify': u'https://open.spotify.com/artist/1eSLQvCYcfd5f1jgxBGbKJ'},
#     u'href': u'https://api.spotify.com/v1/artists/1eSLQvCYcfd5f1jgxBGbKJ',
#     u'id': u'1eSLQvCYcfd5f1jgxBGbKJ',
#     u'name': u'100 Kila',
#     u'type': u'artist',
#     u'uri': u'spotify:artist:1eSLQvCYcfd5f1jgxBGbKJ'}],
#   u'available_markets': [u'AD',
#    u'AR',
#    u'AT',
#    u'AU',
#    u'BE',
#    u'BG',
#    u'BO',
#    u'BR',
#    u'CA',
#    u'CH',
#    u'CL',
#    u'CO',
#    u'CR',
#    u'CY',
#    u'CZ',
#    u'DE',
#    u'DK',
#    u'DO',
#    u'EC',
#    u'EE',
#    u'ES',
#    u'FI',
#    u'FR',
#    u'GB',
#    u'GR',
#    u'GT',
#    u'HK',
#    u'HN',
#    u'HU',
#    u'ID',
#    u'IE',
#    u'IS',
#    u'IT',
#    u'JP',
#    u'LI',
#    u'LT',
#    u'LU',
#    u'LV',
#    u'MC',
#    u'MT',
#    u'MX',
#    u'MY',
#    u'NI',
#    u'NL',
#    u'NO',
#    u'NZ',
#    u'PA',
#    u'PE',
#    u'PH',
#    u'PL',
#    u'PT',
#    u'PY',
#    u'SE',
#    u'SG',
#    u'SK',
#    u'SV',
#    u'TR',
#    u'TW',
#    u'US',
#    u'UY'],
#   u'external_urls': {u'spotify': u'https://open.spotify.com/album/6wWp5IFhz1pl6St9V04sFy'},
#   u'href': u'https://api.spotify.com/v1/albums/6wWp5IFhz1pl6St9V04sFy',
#   u'id': u'6wWp5IFhz1pl6St9V04sFy',
#   u'images': [{u'height': 640,
#     u'url': u'https://i.scdn.co/image/3ab246c7fc9f37783540cbdc55c7a80325e685de',
#     u'width': 640},
#    {u'height': 300,
#     u'url': u'https://i.scdn.co/image/6ba45c5cb25f46e7432390e29a20ba71e283efdf',
#     u'width': 300},
#    {u'height': 64,
#     u'url': u'https://i.scdn.co/image/60b605fbf2e99179ce920d7d83e87e7cb2643cea',
#     u'width': 64}],
#   u'name': u'\u0411\u0430\u0432\u0430\u0440\u0435\u0446\u0430',
#   u'type': u'album',
#   u'uri': u'spotify:album:6wWp5IFhz1pl6St9V04sFy'},
#  u'spotify_artist_id': u'1eSLQvCYcfd5f1jgxBGbKJ'}

# %% [markdown]
# # Apply "topics" to artists

# %%
# so far I haven't found a single piece of metadata that gives me a good language filter
# I'm wondering if my next step should be to identify the songs of different languages
# using the stop words from nltk or a language identifying package

# %%
# for the first pass at the project I'll ignore the above and move onto classifying my artists by topic

# notes for using cosine similarity
# from sklearn.metrics.pairwise import cosine_similarity
# cosine_similarity(W_sklearn[0:1], W_sklearn)

# %%
# lets create a list of the topics for every artist
artist_topics = [artist.argmax() for artist in W_sklearn]

# %% [markdown]
# # Visualize grouped artists

# %%
# lets take at our topic distributions
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# plot topic distributions
plt.figure(figsize=(10,7))
plt.hist(artist_topics, bins=30)
plt.show()

# %%
# seems Topic 1 is by far the most dominant class

# %%
artist_and_topic = []
for i in xrange(len(artist_topics)):
    artist_and_topic.append((lyrics_by_artist_df['musician_name'][i], artist_topics[i]))

# %%
artist_topic_df = pd.DataFrame.from_records(data=artist_and_topic,columns=[['musician_name','topic']])

# %% [markdown]
# # Play around with visualization options

# %%
artist_topic_df.head()
# Out:
#      musician_name  topic
# 0             100s      1
# 1              112     29
# 2  1200 Techniques      5
# 3         2 Chainz      5
# 4      2 Live Crew     13

# %%
# lets create a dictionary of top words per topic
topic_dict = {}
for topic_num, topic in enumerate(H_sklearn):
        topic_dict[topic_num] = " ".join([feature_words[i] for i in topic.argsort()[:-15 - 1:-1]])

# %%
topic_dict
# Out:
# {0: u'im dont just thats aint cause like ive ill feel think better imma time need',
#  1: u'nigga fuck shit bitch aint know im gon money em dont real young bout make',
#  2: u'le \xe0 je et dans que pa qui la cest est comme en mais tu',
#  3: u'girl love baby wanna oh let want know just make hey time come youre like',
#  4: u'i\u2019m don\u2019t it\u2019s ain\u2019t like that\u2019s just know can\u2019t i\u2019ll you\u2019re \u2018em say tell i\u2019ve',
#  5: u'got money im aint like man just girl young trap tryna shit gotta new cash',
#  6: u'que y en el mi te tu por lo se la para como e los',
#  7: u'like know im make ya beat flow  rap style hit wa new got car',
#  8: u'und ich ist der nicht wir du wie auf sie mit zu f\xfcr die ein',
#  9: u'je se za sve da ne sam ja kad na mi ko smo samo ti',
#  10: u'bitch hoe lil pussy dick imma ho fuck like money aint yo know dont bad',
#  11: u'\ub09c \ub0b4 \ub0b4\uac00 \ub2e4 \ub0a0 \ub10c \uc774 \ub354 \ub098\uc758 \uc218 \ub610 \uc548 \ub098\ub294 \uadf8 \ub2c8',
#  12: u'yo yall im shit got wit ya man street thats rap black uh wa aint',
#  13: u'cause rhyme im mc youre dont funky mic yo rock come got brother time man',
#  14: u'yeah oh mmm just hmmm know like im everybody uh decatur em hell tell feel',
#  15: u'la got hey gangsta jump oh dont milf youre blas\xe9 zaccka thuggin badman glamorous like',
#  16: u'che il \xe8 e non di sono io mi se una la pi\xf9 quando ci',
#  17: u'na dey eh ni o wo nwa oya asa yeh nie baby e obianuju kukere',
#  18: u' im uh ya aint ta like dont yall come booty 2x beat 0 chigga',
#  19: u'life time u make god love day just mind world people soul eye youre black',
#  20: u'fuck shit bitch fucking dick motherfucker dont got like fuckin cause just kill fucked gun',
#  21: u'wa just said man cause aint say thought like really good got didnt know knew',
#  22: u'im ya got gangsta cause aint nigga wit dogg g chorus game dont fool wanna',
#  23: u'im big boy cause know got aint like hoe moe trunk playa ya ima mayn',
#  24: u'bmi ascap produced music publishing published additional recorded studio llc written j mixed featuring adm',
#  25: u'em let like ya make air dont clap drop fall hit hand 3x u say',
#  26: u'dem mi di gyal yuh vibe hotta nuh inna bad fi seh ting gal say',
#  27: u'feat prod monty  ft love tracklist ayy themind know 14 7 2 11 im',
#  28: u'da dat wit law ya break bay ay palmdale betta tha yo dont wanna ba',
#  29: u'know dont aint like just tell wanna thats want say man let come cause way'}

# %%
artist_topic_df.head()
# Out:
#      musician_name  topic
# 0             100s      1
# 1              112     29
# 2  1200 Techniques      5
# 3         2 Chainz      5
# 4      2 Live Crew     13

# %%
song_dev.find({})

# %%
artist_topic_df[['musician_name','topic']][:]
# Out:
#              musician_name  topic
# 0                     100s      1
# 1                      112     29
# 2          1200 Techniques      5
# 3                 2 Chainz      5
# 4              2 Live Crew     13
# 5                2 Pistols      5
# 6            2 Skinnee J's      7
# 7                21 Savage      1
# 8                     2Mex     19
# 9              2nd II None     22
# 10                3X Krazy     22
# 11                3rd Bass     13
# 12                40 Glocc     22
# 13                   43zla      9
# 14                 50 Cent      1
# 15                504 Boyz     23
# 16           5th Ward Boyz      1
# 17                 69 Boyz     28
# 18       7 Notas 7 Colores      6
# 19             8Ball & MJG     23
# 20                95 South     28
# 21                99 Posse     16
# 22              9th Wonder     21
# 23    A Tribe Called Quest     13
# 24                     AMG     28
# 25                      AZ      1
# 26                 Ab-Soul     24
# 27           Above the Law     13
# 28           Abstract Rude      0
# 29                Ace Hood      1
# ...                    ...    ...
# 1082                    XV      4
# 1083                Xzibit      1
# 1084                    YG      1
# 1085                    YZ      4
# 1086                Ya Boy      0
# 1087          Yaggfu Front     13
# 1088              Yelawolf     20
# 1089       Ying Yang Twins     28
# 1090              Yo Gotti      1
# 1091     Yo Yo Honey Singh     17
# 1092           Young Bleed      1
# 1093            Young Buck      1
# 1094            Young Chop      1
# 1095             Young Dro     10
# 1096              Young MC     13
# 1097          Young Maylay     23
# 1098           Young Noble      7
# 1099       Young Paperboyz      1
# 1100         Young Scooter      5
# 1101            Young Thug      5
# 1102        Your Old Droog      4
# 1103              Yukmouth      1
# 1104             Yung Berg      3
# 1105              Yung Joc      1
# 1106             Yung Lean     27
# 1107              Yung Wun     29
# 1108               Yung6ix     17
# 1109                  Z-Ro     23
# 1110            Zebra Katz     10
# 1111                Zion I     19
#
# [1112 rows x 2 columns]

# %%
cluster_colors = {0: '#CCFFCC', 1: '#CCFFFF', 2: '#FFFF99', 3: '#CCCC66', 4: '#FFFF00', \
                  5: '#CCCCFF', 6: '#CCCCCC', 7: '#FFCCCC', 8: '#FFCC99', 9: '#FFCC00', \
                  10: '#CC9966', 11: '#FF99FF', 12: '#FF9900', 13: '#CC6633', 14: '#FF6600', \
                  15: '#CC3333', 16: '#FF3366',  17: '#660066', 18: '#660000', 19: '#6600FF', \
                  20: '#663300', 21: '#666600', 22: '#6666FF', 23: '#669900', 24: '#669999', \
                  25: '#6699CC', 26: '#66CC00', 27: '#00FF33',28: '#006666',29: '#000000'}cluster_colors = {0: '#CCFFCC', 1: '#CCFFFF', 2: '#FFFF99', 3: '#CCCC66', 4: '#FFFF00', \
                  5: '#CCCCFF', 6: '#CCCCCC', 7: '#FFCCCC', 8: '#FFCC99', 9: '#FFCC00', \
                  10: '#CC9966', 11: '#FF99FF', 12: '#FF9900', 13: '#CC6633', 14: '#FF6600', \
                  15: '#CC3333', 16: '#FF3366',  17: '#660066', 18: '#660000', 19: '#6600FF', \
                  20: '#663300', 21: '#666600', 22: '#6666FF', 23: '#669900', 24: '#669999', \
                  25: '#6699CC', 26: '#66CC00', 27: '#00FF33',28: '#006666',29: '#000000'}

# %%
cluster_colors
# Out:
# {0: '#CCFFCC',
#  1: '#CCFFFF',
#  2: '#FFFF99',
#  3: '#CCCC66',
#  4: '#FFFF00',
#  5: '#CCCCFF',
#  6: '#CCCCCC',
#  7: '#FFCCCC',
#  8: '#FFCC99',
#  9: '#FFCC00',
#  10: '#CC9966',
#  11: '#FF99FF',
#  12: '#FF9900',
#  13: '#CC6633',
#  14: '#FF6600',
#  15: '#CC3333',
#  16: '#FF3366',
#  17: '#660066',
#  18: '#660000',
#  19: '#6600FF',
#  20: '#663300',
#  21: '#666600',
#  22: '#6666FF',
#  23: '#669900',
#  24: '#669999',
#  25: '#6699CC',
#  26: '#66CC00',
#  27: '#00FF33',
#  28: '#006666',
#  29: '#000000'}

# %%
groups = artist_topic_df.groupby('topic')

# %%
fig, ax = plt.subplots(figsize=(10, 5)) # set size
ax.margins(0.05) # Optional, just adds 5% padding to the autoscaling
N = 30
data = np.random.random((N, 4))
labels = ['point{0}'.format(i) for i in range(N)]
plt.subplots_adjust(bottom = 0.1)
plt.scatter(
    data[:, 0], data[:, 1], marker = 'o', c = data[:, 2], s = data[:, 3]*1500,
    cmap = plt.get_cmap('Spectral'))
for label, x, y in zip(labels, data[:, 0], data[:, 1]):
    plt.annotate(
        label, 
        xy = (x, y), xytext = (-20, 20),
        textcoords = 'offset points', ha = 'right', va = 'bottom',
        bbox = dict(boxstyle = 'round,pad=0.5', fc = 'yellow', alpha = 0.5),
        arrowprops = dict(arrowstyle = '->', connectionstyle = 'arc3,rad=0'))

plt.show()

# %%
from matplotlib.pyplot import figure, show
import numpy as npy
from numpy.random import rand

if 1: # picking on a scatter plot (matplotlib.collections.RegularPolyCollection)

    x, y, c, s = rand(4, 100)
    def onpick3(event):
        ind = event.ind
        print 'onpick3 scatter:', ind, npy.take(x, ind), npy.take(y, ind)

    fig, ax1 = plt.subplots(figsize=(10, 5)) # set size
    ax1.margins(0.05) # Optional, just adds 5% padding to the autoscaling
    ax1 = fig.add_subplot(111)
    col = ax1.scatter(x, y, 100*s, c, picker=True)
    #fig.savefig('pscoll.eps')
    fig.canvas.mpl_connect('pick_event', onpick3)

show()

# %%
import matplotlib.pyplot as plt
import scipy.spatial as spatial
import numpy as np
pi = np.pi
cos = np.cos

def fmt(x, y):
    return 'x: {x:0.2f}\ny: {y:0.2f}'.format(x=x, y=y)

class FollowDotCursor(object):
    """Display the x,y location of the nearest data point.
    http://stackoverflow.com/a/4674445/190597 (Joe Kington)
    http://stackoverflow.com/a/13306887/190597 (unutbu)
    http://stackoverflow.com/a/15454427/190597 (unutbu)
    """
    def __init__(self, ax, x, y, tolerance=5, formatter=fmt, offsets=(-20, 20)):
        try:
            x = np.asarray(x, dtype='float')
        except (TypeError, ValueError):
            x = np.asarray(mdates.date2num(x), dtype='float')
        y = np.asarray(y, dtype='float')
        mask = ~(np.isnan(x) | np.isnan(y))
        x = x[mask]
        y = y[mask]
        self._points = np.column_stack((x, y))
        self.offsets = offsets
        y = y[np.abs(y-y.mean()) <= 3*y.std()]
        self.scale = x.ptp()
        self.scale = y.ptp() / self.scale if self.scale else 1
        self.tree = spatial.cKDTree(self.scaled(self._points))
        self.formatter = formatter
        self.tolerance = tolerance
        self.ax = ax
        self.fig = ax.figure
        self.ax.xaxis.set_label_position('top')
        self.dot = ax.scatter(
            [x.min()], [y.min()], s=130, color='green', alpha=0.7)
        self.annotation = self.setup_annotation()
        plt.connect('motion_notify_event', self)

    def scaled(self, points):
        points = np.asarray(points)
        return points * (self.scale, 1)

    def __call__(self, event):
        ax = self.ax
        # event.inaxes is always the current axis. If you use twinx, ax could be
        # a different axis.
        if event.inaxes == ax:
            x, y = event.xdata, event.ydata
        elif event.inaxes is None:
            return
        else:
            inv = ax.transData.inverted()
            x, y = inv.transform([(event.x, event.y)]).ravel()
        annotation = self.annotation
        x, y = self.snap(x, y)
        annotation.xy = x, y
        annotation.set_text(self.formatter(x, y))
        self.dot.set_offsets((x, y))
        bbox = ax.viewLim
        event.canvas.draw()

    def setup_annotation(self):
        """Draw and hide the annotation box."""
        annotation = self.ax.annotate(
            '', xy=(0, 0), ha = 'right',
            xytext = self.offsets, textcoords = 'offset points', va = 'bottom',
            bbox = dict(
                boxstyle='round,pad=0.5', fc='yellow', alpha=0.75),
            arrowprops = dict(
                arrowstyle='->', connectionstyle='arc3,rad=0'))
        return annotation

    def snap(self, x, y):
        """Return the value in self.tree closest to x, y."""
        dist, idx = self.tree.query(self.scaled((x, y)), k=1, p=1)
        try:
            return self._points[idx]
        except IndexError:
            # IndexError: index out of bounds
            return self._points[0]

fig, ax = plt.subplots()
x = np.linspace(0.1, 2*pi, 10)
y = cos(x)
markerline, stemlines, baseline = ax.stem(x, y, '-.')
plt.setp(markerline, 'markerfacecolor', 'b')
plt.setp(baseline, 'color','r', 'linewidth', 2)
cursor = FollowDotCursor(ax, x, y, tolerance=20)
plt.show()

# %%
import mpld3

mpld3.enable_notebook()

# %%
fig, ax = plt.subplots(subplot_kw=dict(axisbg='#EEEEEE'),figsize=(10, 5))
ax.grid(color='white', linestyle='solid')
ax1.margins(0.05) # Optional, just adds 5% padding to the autoscaling

N = 50
scatter = ax.scatter(np.random.normal(size=N),
                     np.random.normal(size=N),
                     c=np.random.random(size=N),
                     s = 1000 * np.random.random(size=N),
                     alpha=0.3,
                     cmap=plt.cm.jet)

ax.set_title("D3 Scatter Plot", size=18)

# %%
from mpld3 import plugins

fig, ax = plt.subplots(subplot_kw=dict(axisbg='#EEEEEE'))
ax.grid(color='white', linestyle='solid')

N = 50
scatter = ax.scatter(np.random.normal(size=N),
                     np.random.normal(size=N),
                     c=np.random.random(size=N),
                     s = 1000 * np.random.random(size=N),
                     alpha=0.3,
                     cmap=plt.cm.jet)

ax.set_title("D3 Scatter Plot (with tooltips!)", size=20)

labels = ['point {0}'.format(i + 1) for i in range(N)]
fig.plugins = [plugins.PointLabelTooltip(scatter, labels)]

# %%
scatter

# %%
from bokeh.models import HoverTool, ColumnDataSource
from bokeh.plotting import figure, show
from bokeh.sampledata.periodic_table import elements

romans = ["I", "II", "III", "IV", "V", "VI", "VII"]

elements["atomic mass"] = elements["atomic mass"].astype(str)

elements["period"] = [romans[x-1] for x in elements.period]
elements = elements[elements.group != "-"]

group_range = [str(x) for x in range(1, 19)]

colormap = {
    "alkali metal"         : "#a6cee3",
    "alkaline earth metal" : "#1f78b4",
    "halogen"              : "#fdbf6f",
    "metal"                : "#b2df8a",
    "metalloid"            : "#33a02c",
    "noble gas"            : "#bbbb88",
    "nonmetal"             : "#baa2a6",
    "transition metal"     : "#e08e79",
}

source = ColumnDataSource(
    data=dict(
        group=[str(x) for x in elements["group"]],
        period=[str(y) for y in elements["period"]],
        symx=[str(x)+":0.1" for x in elements["group"]],
        numbery=[str(x)+":0.8" for x in elements["period"]],
        massy=[str(x)+":0.15" for x in elements["period"]],
        namey=[str(x)+":0.3" for x in elements["period"]],
        sym=elements["symbol"],
        name=elements["name"],
        cpk=elements["CPK"],
        atomic_number=elements["atomic number"],
        electronic=elements["electronic configuration"],
        mass=elements["atomic mass"],
        type=elements["metal"],
        type_color=[colormap[x] for x in elements["metal"]],
    )
)

p = figure(title="Periodic Table", tools="hover,save",
           x_range=group_range, y_range=list(reversed(romans)))
p.plot_width = 1200
p.toolbar_location = None
p.outline_line_color = None

p.rect("group", "period", 0.9, 0.9, source=source,
       fill_alpha=0.6, color="type_color")

text_props = {
    "source": source,
    "angle": 0,
    "color": "black",
    "text_align": "left",
    "text_baseline": "middle"
}

p.text(x="symx", y="period", text="sym",
       text_font_style="bold", text_font_size="15pt", **text_props)

p.text(x="symx", y="numbery", text="atomic_number",
       text_font_size="9pt", **text_props)

p.text(x="symx", y="namey", text="name",
       text_font_size="6pt", **text_props)

p.text(x="symx", y="massy", text="mass",
       text_font_size="5pt", **text_props)

p.grid.grid_line_color = None

p.select_one(HoverTool).tooltips = [
    ("name", "@name"),
    ("atomic number", "@atomic_number"),
    ("type", "@type"),
    ("atomic mass", "@mass"),
    ("CPK color", "$color[hex, swatch]:cpk"),
    ("electronic configuration", "@electronic"),
]

show(p)  # Change to save(p) to save but not show the HTML file
# Out:
# /Users/sean/anaconda2/lib/python2.7/site-packages/bokeh/core/properties.py:455: DeprecationWarning: Setting a fixed font size value as a string '15pt' is deprecated, set with value('15pt') or ['15pt'] instead
#   value = self.descriptor.prepare_value(obj.__class__, self.name, value)
# /Users/sean/anaconda2/lib/python2.7/site-packages/bokeh/core/properties.py:455: DeprecationWarning: Setting a fixed font size value as a string '15pt' is deprecated, set with value('15pt') or ['15pt'] instead
#   value = self.descriptor.prepare_value(obj.__class__, self.name, value)
# /Users/sean/anaconda2/lib/python2.7/site-packages/bokeh/core/properties.py:455: DeprecationWarning: Setting a fixed font size value as a string '9pt' is deprecated, set with value('9pt') or ['9pt'] instead
#   value = self.descriptor.prepare_value(obj.__class__, self.name, value)
# /Users/sean/anaconda2/lib/python2.7/site-packages/bokeh/core/properties.py:455: DeprecationWarning: Setting a fixed font size value as a string '9pt' is deprecated, set with value('9pt') or ['9pt'] instead
#   value = self.descriptor.prepare_value(obj.__class__, self.name, value)
# /Users/sean/anaconda2/lib/python2.7/site-packages/bokeh/core/properties.py:455: DeprecationWarning: Setting a fixed font size value as a string '6pt' is deprecated, set with value('6pt') or ['6pt'] instead
#   value = self.descriptor.prepare_value(obj.__class__, self.name, value)
# /Users/sean/anaconda2/lib/python2.7/site-packages/bokeh/core/properties.py:455: DeprecationWarning: Setting a fixed font size value as a string '6pt' is deprecated, set with value('6pt') or ['6pt'] instead
#   value = self.descriptor.prepare_value(obj.__class__, self.name, value)
# /Users/sean/anaconda2/lib/python2.7/site-packages/bokeh/core/properties.py:455: DeprecationWarning: Setting a fixed font size value as a string '5pt' is deprecated, set with value('5pt') or ['5pt'] instead
#   value = self.descriptor.prepare_value(obj.__class__, self.name, value)
# /Users/sean/anaconda2/lib/python2.7/site-packages/bokeh/core/properties.py:455: DeprecationWarning: Setting a fixed font size value as a string '5pt' is deprecated, set with value('5pt') or ['5pt'] instead
#   value = self.descriptor.prepare_value(obj.__class__, self.name, value)
